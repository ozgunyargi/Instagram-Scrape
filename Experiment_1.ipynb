# %% [markdown]
# # Instagram Bot Classification

# %% [markdown]
# ## Import Libraries

# %%
import glob, os, json, time
import numpy as np
import networkx as nx
import pandas as pd
import xgboost as xgb
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.decomposition import PCA
from tqdm import  tqdm
from scipy import spatial
from InstaScrape.Config.config import *
from Feature_Extraction.Feature_Extraction import get_the_models
from Network.Create_network import extract_network_features

# %% [markdown]
# ## Get the data

# %%
df = pd.read_csv("labels.csv", index_col=0)

df
# Out:
#                             labels
# skills_and_growth        Inorganic
# amazingdecorjakarta        Organic
# dr.thema                   Organic
# shrinkchicks             Inorganic
# _birb_memes_             Inorganic
# ...                            ...
# energialifestyles        Inorganic
# thediaryofagoddess       Inorganic
# think.geography          Inorganic
# microbiologylifevilnius  Inorganic
# crystlelampitt           Inorganic
#
# [344 rows x 1 columns]

# %% [markdown]
# ## Functions

# %%
def cosine_similarity(mylist):

    if len(mylist) > 1:
        similarities = []
        for i in range(len(mylist)-1):
            for j in range(i+1, len(mylist)):
                similarity = 1 - spatial.distance.cosine(mylist[i], mylist[j])
                similarities.append(similarity)
        similarities = np.array(similarities)

        return {"cos_sim_mean": np.mean(similarities), "cos_sim_var": np.var(similarities) }
    else:
        return {"cos_sim_mean": 0, "cos_sim_var": 0}

# %%
def get_mean_embeddings(mylist):
    mylist = np.array(mylist)

    return np.mean(mylist,axis=0)

# %%
def getmetadata(acc_p, log_features = ["posts", "followers", "following"]):
    """
    Returns a dictionary that holds specific information about #posts,
    #followers, #followings, isverified or not for each account.
    """
    mydict_ = {}
    name_ = os.path.basename(acc_p)

    with open(acc_p+"/{}.json".format(name_)) as myfile:
        opened = json.load(myfile)

        for fea in log_features:
            mydict_[fea] = opened[fea]
            mydict_[f"{fea}_log"] = np.log1p(opened[fea])

        mydict_["verified"] = opened["verified"]
    return mydict_

# %%
def to_df_dict(mydict):

    df_dict = {}

    for account_name in mydict.keys():
        ghost_dict = {}
        for sec_key in mydict[account_name].keys():
            for fea in  mydict[account_name][sec_key].keys():
                if sec_key == "network":
                    for net_fea in mydict[account_name][sec_key][fea].keys():
                        ghost_dict[f"{fea}_{net_fea}"] = mydict[account_name][sec_key][fea][net_fea]
                else:
                    ghost_dict[fea] = mydict[account_name][sec_key][fea]
        df_dict[account_name] = ghost_dict

    return df_dict

# %%
def executePCA(df_temp, num_of_fea=100):
    """
    Finds the PCA components of willing feature vector.
    """

    model_ = PCA(n_components=num_of_fea, svd_solver="arpack")
    df_temp = model_.fit_transform(df_temp)
    return df_temp

# %%
def expand_cols(dataframe, cols=["image_embedding", "caption_embedding"], pca_pars = [150,100]):
    df_ = dataframe.copy()

    for indx, col in enumerate(cols):
        arr = np.vstack(df_[col])
        arr = executePCA(arr, pca_pars[indx])
        df_temp = pd.DataFrame(arr, index=df_.index, columns=[f"{col}_{x}" for x in range(arr.shape[1])])
        df_ = df_.merge(df_temp, left_index=True, right_index=True)

    df_.drop(cols, axis=1, inplace=True)
    return df_

# %%
def normalize_columns(df_trn, df_tst, sca_type= "MinMaxScaler"):
    """
    Normalizes all numeric columns by using MinMaxScaler

    :param df_trn: DataFrame
    :param df_tst: DataFrame
    :return: DataFrame, DataFrame
    """

    if sca_type == "MinMaxScaler":
        scaler = MinMaxScaler()

    else:
        scaler = StandardScaler()

    df_train = df_trn.copy()
    df_test = df_tst.copy()
    numeric_cols = df_train.dtypes.index[((df_train.dtypes != "object") & (df_train.dtypes != bool))]

    ct = ColumnTransformer([('SS', scaler, numeric_cols)], remainder='passthrough')
    df_train[numeric_cols] = ct.fit_transform(df_train[numeric_cols])
    df_test[numeric_cols] = ct.transform(df_test[numeric_cols])

    return df_train, df_test

# %%
def convert_bools(dataframe):
    """
    Converts all boolean and string True/False elements to 1 and 0.
    True: 1
    False: 0

    :param dataframe: DataFrame
    :return: DataFrame
    """

    df = dataframe.copy()
    none_int_cols = df.dtypes.index[(df.dtypes != "int64") == True]
    df[none_int_cols] = df[none_int_cols].applymap(lambda x: 0 if x == "False" or x == False else x)
    df[none_int_cols] = df[none_int_cols].applymap(lambda x: 1 if x == "True" or x == True else x)

    return df

# %% [markdown]
# ## Main

# %%
pbar = tqdm(glob.glob(f"{DATA_PATH_}/*"))
mynetworks = ["comment", "hashtag", "tag"]
feature_dict ={}

for folder_path in pbar:
    acc_name = os.path.basename(folder_path)

    files = glob.glob(f"{folder_path}/[!{acc_name},!features]*.json")
    meta_file = f"{folder_path}/{acc_name}.json"
    image_text_features = f"{folder_path}/features.json"

    image_embeddings = []
    caption_embeddings = []
    comment_similarities = []


    # IMAGE AND TEXT FEATURES
    with open(image_text_features) as features_file:
        data = json.load(features_file)

        for post in data:
            pbar.set_description(f"Collecting Features of {acc_name} => {post}: ")


            image_embedding =  data[post]["image_features"]
            caption_embedding = data[post]["text_features"]["caption"]
            comment_embedding = data[post]["text_features"]["comments"]
            comment_embedding = [np.array(x) for x in comment_embedding]

            comments_cos_sim = cosine_similarity(comment_embedding)

            image_embeddings.append(image_embedding)
            caption_embeddings.append(caption_embedding)
            comment_similarities.append(comments_cos_sim["cos_sim_mean"])

    # NETWORK FEATURES
    network_files = [nx.readwrite.gexf.read_gexf(f"{folder_path}/{acc_name}_{network}_network.gexf") for network in mynetworks]


    feature_dict[acc_name] = {"image": {"image_embedding": get_mean_embeddings(image_embeddings),
                                    "image_cos_sim_mean": cosine_similarity(image_embeddings)["cos_sim_mean"],
                                    "image_cos_sim_var": cosine_similarity(image_embeddings)["cos_sim_var"]},
                              "text": {"caption_embedding": get_mean_embeddings(caption_embeddings),
                                    "caption_cos_sim_mean": cosine_similarity(caption_embeddings)["cos_sim_mean"],
                                    "caption_cos_sim_var":cosine_similarity(caption_embeddings)["cos_sim_var"],
                                    "comments_cos_sim_mean": cosine_similarity(comment_similarities)["cos_sim_mean"]},
                             "network": {"comment_network": extract_network_features(network_files[0]),
                                   "hashtag_network":extract_network_features(network_files[1]),
                                   "tag_network":extract_network_features(network_files[2])},
                              "metadata": getmetadata(folder_path)
                             }

# %%
df_raw = pd.DataFrame.from_dict(to_df_dict(feature_dict), orient="index")

# %%
df_raw = expand_cols(df_raw)

# %%
df_raw.fillna(0, inplace=True)

# %%
df = pd.merge(df_raw, df, left_index=True, right_index=True)

# %% [markdown]
# ### Train-Test Split

# %%
sss = StratifiedShuffleSplit(n_splits=10, test_size=0.3, random_state= 42)


le = LabelEncoder()
le.fit(df["labels"]).classes_
# Out:
# array(['Inorganic', 'Organic'], dtype=object)

# %%
df["labels"] = df["labels"].apply(lambda x: 0 if x == "Inorganic" else 1)

# %%
y = df["labels"]
X = df.drop("labels", axis=1)

# %%
# Parameter
param = {'max_depth': 30,
         'eta': 0.001,
         'objective': 'binary:hinge',
         "nthread" : 4,
         "eval_metric" : "auc"}

num_round = 800

# %%
# Stratified train-test split
f1_scores = []

for train_index, test_index in sss.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = pd.DataFrame(y).iloc[train_index], pd.DataFrame(y).iloc[test_index]

    oversample = SMOTE()
    X_train, y_train = oversample.fit_resample(X_train,y_train)
    X_train, X_test = normalize_columns(X_train, X_test)
    X_train = convert_bools(X_train)
    X_test = convert_bools(X_test)

    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval'), (dtrain, 'train')]
    bst = xgb.train(param, dtrain, num_round, evallist)
    mypreds = bst.predict(dtest)
    f1_scores.append(f1_score(y_test, mypreds, average="binary"))
# Out:
# [0]	eval-auc:0.50000	train-auc:0.50000
# [1]	eval-auc:0.50000	train-auc:0.50000
# [2]	eval-auc:0.50000	train-auc:0.50000
# [3]	eval-auc:0.50000	train-auc:0.50000
# [4]	eval-auc:0.50000	train-auc:0.50000
# [5]	eval-auc:0.50000	train-auc:0.50000
# [6]	eval-auc:0.50000	train-auc:0.50000
# [7]	eval-auc:0.50000	train-auc:0.50000
# [8]	eval-auc:0.50000	train-auc:0.50000
# [9]	eval-auc:0.50000	train-auc:0.50000
# [10]	eval-auc:0.50000	train-auc:0.50000
# [11]	eval-auc:0.50000	train-auc:0.50000
# [12]	eval-auc:0.50000	train-auc:0.50000
# [13]	eval-auc:0.50000	train-auc:0.50000
# [14]	eval-auc:0.50000	train-auc:0.50000
# [15]	eval-auc:0.50000	train-auc:0.50000
# [16]	eval-auc:0.50000	train-auc:0.50000
# [17]	eval-auc:0.50000	train-auc:0.50000
# [18]	eval-auc:0.50000	train-auc:0.50000
# [19]	eval-auc:0.50000	train-auc:0.50000
# [20]	eval-auc:0.50000	train-auc:0.50000
# [21]	eval-auc:0.50000	train-auc:0.50000
# [22]	eval-auc:0.50000	train-auc:0.50000
# [23]	eval-auc:0.50000	train-auc:0.50000
# [24]	eval-auc:0.50000	train-auc:0.50000
# [25]	eval-auc:0.50000	train-auc:0.50000
# [26]	eval-auc:0.50000	train-auc:0.50000
# [27]	eval-auc:0.50000	train-auc:0.50000
# [28]	eval-auc:0.50000	train-auc:0.50000
# [29]	eval-auc:0.50000	train-auc:0.50000
# [30]	eval-auc:0.50000	train-auc:0.50000
# [31]	eval-auc:0.50000	train-auc:0.50000
# [32]	eval-auc:0.50000	train-auc:0.50000
# [33]	eval-auc:0.50000	train-auc:0.50000
# [34]	eval-auc:0.50000	train-auc:0.50000
# [35]	eval-auc:0.50000	train-auc:0.50000
# [36]	eval-auc:0.50000	train-auc:0.50000
# [37]	eval-auc:0.50000	train-auc:0.50000
# [38]	eval-auc:0.50000	train-auc:0.50000
# [39]	eval-auc:0.50000	train-auc:0.50000
# [40]	eval-auc:0.50000	train-auc:0.50000
# [41]	eval-auc:0.50000	train-auc:0.50000
# [42]	eval-auc:0.50000	train-auc:0.50000
# [43]	eval-auc:0.50000	train-auc:0.50000
# [44]	eval-auc:0.50000	train-auc:0.50000
# [45]	eval-auc:0.50000	train-auc:0.50000
# [46]	eval-auc:0.50000	train-auc:0.50000
# [47]	eval-auc:0.50000	train-auc:0.50000
# [48]	eval-auc:0.50000	train-auc:0.50000
# [49]	eval-auc:0.50000	train-auc:0.50000
# [50]	eval-auc:0.50000	train-auc:0.50000
# [51]	eval-auc:0.50000	train-auc:0.50000
# [52]	eval-auc:0.50000	train-auc:0.50000
# [53]	eval-auc:0.50000	train-auc:0.50000
# [54]	eval-auc:0.50000	train-auc:0.50000
# [55]	eval-auc:0.50000	train-auc:0.50000
# [56]	eval-auc:0.50000	train-auc:0.50000
# [57]	eval-auc:0.50000	train-auc:0.50000
# [58]	eval-auc:0.50000	train-auc:0.50000
# [59]	eval-auc:0.50000	train-auc:0.50000
# [60]	eval-auc:0.50000	train-auc:0.50000
# [61]	eval-auc:0.50000	train-auc:0.50000
# [62]	eval-auc:0.50000	train-auc:0.50000
# [63]	eval-auc:0.50000	train-auc:0.50000
# [64]	eval-auc:0.50000	train-auc:0.50000
# [65]	eval-auc:0.50000	train-auc:0.50000
# [66]	eval-auc:0.50000	train-auc:0.50000
# [67]	eval-auc:0.50000	train-auc:0.50000
# [68]	eval-auc:0.50000	train-auc:0.50000
# [69]	eval-auc:0.50000	train-auc:0.50000
# [70]	eval-auc:0.50000	train-auc:0.50000
# [71]	eval-auc:0.50000	train-auc:0.50000
# [72]	eval-auc:0.50000	train-auc:0.50000
# [73]	eval-auc:0.50000	train-auc:0.50000
# [74]	eval-auc:0.50000	train-auc:0.50000
# [75]	eval-auc:0.50000	train-auc:0.50000
# [76]	eval-auc:0.50000	train-auc:0.50000
# [77]	eval-auc:0.50000	train-auc:0.50000
# [78]	eval-auc:0.50000	train-auc:0.50000
# [79]	eval-auc:0.50000	train-auc:0.50000
# [80]	eval-auc:0.50000	train-auc:0.50000
# [81]	eval-auc:0.50000	train-auc:0.50000
# [82]	eval-auc:0.50000	train-auc:0.50000
# [83]	eval-auc:0.50000	train-auc:0.50000
# [84]	eval-auc:0.50000	train-auc:0.50000
# [85]	eval-auc:0.50000	train-auc:0.50000
# [86]	eval-auc:0.50000	train-auc:0.50000
# [87]	eval-auc:0.50000	train-auc:0.50000
# [88]	eval-auc:0.50000	train-auc:0.50000
# [89]	eval-auc:0.50000	train-auc:0.50000
# [90]	eval-auc:0.50000	train-auc:0.50000
# [91]	eval-auc:0.50000	train-auc:0.50000
# [92]	eval-auc:0.50000	train-auc:0.50000
# [93]	eval-auc:0.50000	train-auc:0.50000
# [94]	eval-auc:0.50000	train-auc:0.50000
# [95]	eval-auc:0.50000	train-auc:0.50000
# [96]	eval-auc:0.50000	train-auc:0.50000
# [97]	eval-auc:0.50000	train-auc:0.50000
# [98]	eval-auc:0.50000	train-auc:0.50000
# [99]	eval-auc:0.50000	train-auc:0.50000
# [100]	eval-auc:0.50000	train-auc:0.50000
# [101]	eval-auc:0.50000	train-auc:0.50000
# [102]	eval-auc:0.50000	train-auc:0.50000
# [103]	eval-auc:0.50000	train-auc:0.50000
# [104]	eval-auc:0.50000	train-auc:0.50000
# [105]	eval-auc:0.50000	train-auc:0.50000
# [106]	eval-auc:0.50000	train-auc:0.50000
# [107]	eval-auc:0.50000	train-auc:0.50000
# [108]	eval-auc:0.50000	train-auc:0.50000
# [109]	eval-auc:0.50000	train-auc:0.50000
# [110]	eval-auc:0.50000	train-auc:0.50000
# [111]	eval-auc:0.50000	train-auc:0.50000
# [112]	eval-auc:0.50000	train-auc:0.50000
# [113]	eval-auc:0.50000	train-auc:0.50000
# [114]	eval-auc:0.50000	train-auc:0.50000
# [115]	eval-auc:0.50000	train-auc:0.50000
# [116]	eval-auc:0.50000	train-auc:0.50000
# [117]	eval-auc:0.50000	train-auc:0.50000
# [118]	eval-auc:0.50000	train-auc:0.50000
# [119]	eval-auc:0.50000	train-auc:0.50000
# [120]	eval-auc:0.50000	train-auc:0.50000
# [121]	eval-auc:0.50000	train-auc:0.50000
# [122]	eval-auc:0.50000	train-auc:0.50000
# [123]	eval-auc:0.50000	train-auc:0.50000
# [124]	eval-auc:0.50000	train-auc:0.50000
# [125]	eval-auc:0.50000	train-auc:0.50000
# [126]	eval-auc:0.50000	train-auc:0.50000
# [127]	eval-auc:0.50000	train-auc:0.50000
# [128]	eval-auc:0.50000	train-auc:0.50000
# [129]	eval-auc:0.50000	train-auc:0.50000
# [130]	eval-auc:0.50000	train-auc:0.50000
# [131]	eval-auc:0.50000	train-auc:0.50000
# [132]	eval-auc:0.50000	train-auc:0.50000
# [133]	eval-auc:0.50000	train-auc:0.50000
# [134]	eval-auc:0.50000	train-auc:0.50000
# [135]	eval-auc:0.50000	train-auc:0.50000
# [136]	eval-auc:0.50000	train-auc:0.50000
# [137]	eval-auc:0.50000	train-auc:0.50000
# [138]	eval-auc:0.50000	train-auc:0.50000
# [139]	eval-auc:0.50000	train-auc:0.50000
# [140]	eval-auc:0.50000	train-auc:0.50000
# [141]	eval-auc:0.50000	train-auc:0.50000
# [142]	eval-auc:0.50000	train-auc:0.50000
# [143]	eval-auc:0.50000	train-auc:0.50000
# [144]	eval-auc:0.50000	train-auc:0.50000
# [145]	eval-auc:0.50000	train-auc:0.50000
# [146]	eval-auc:0.50000	train-auc:0.50000
# [147]	eval-auc:0.50000	train-auc:0.50000
# [148]	eval-auc:0.50000	train-auc:0.50000
# [149]	eval-auc:0.50000	train-auc:0.50000
# [150]	eval-auc:0.50000	train-auc:0.50000
# [151]	eval-auc:0.50000	train-auc:0.50000
# [152]	eval-auc:0.50000	train-auc:0.50000
# [153]	eval-auc:0.50000	train-auc:0.50000
# [154]	eval-auc:0.50000	train-auc:0.50000
# [155]	eval-auc:0.50000	train-auc:0.50000
# [156]	eval-auc:0.50000	train-auc:0.50000
# [157]	eval-auc:0.50000	train-auc:0.50000
# [158]	eval-auc:0.50000	train-auc:0.50000
# [159]	eval-auc:0.50000	train-auc:0.50000
# [160]	eval-auc:0.50000	train-auc:0.50000
# [161]	eval-auc:0.50000	train-auc:0.50000
# [162]	eval-auc:0.50000	train-auc:0.50000
# [163]	eval-auc:0.50000	train-auc:0.50000
# [164]	eval-auc:0.50000	train-auc:0.50000
# [165]	eval-auc:0.50000	train-auc:0.50000
# [166]	eval-auc:0.50000	train-auc:0.50000
# [167]	eval-auc:0.50000	train-auc:0.50000
# [168]	eval-auc:0.50000	train-auc:0.50000
# [169]	eval-auc:0.50000	train-auc:0.50000
# [170]	eval-auc:0.50000	train-auc:0.50000
# [171]	eval-auc:0.50000	train-auc:0.50000
# [172]	eval-auc:0.50000	train-auc:0.50000
# [173]	eval-auc:0.50000	train-auc:0.50000
# [174]	eval-auc:0.50000	train-auc:0.50000
# [175]	eval-auc:0.50000	train-auc:0.50000
# [176]	eval-auc:0.50000	train-auc:0.50000
# [177]	eval-auc:0.50000	train-auc:0.50000
# [178]	eval-auc:0.50000	train-auc:0.50000
# [179]	eval-auc:0.50000	train-auc:0.50000
# [180]	eval-auc:0.50000	train-auc:0.50000
# [181]	eval-auc:0.50000	train-auc:0.50000
# [182]	eval-auc:0.50000	train-auc:0.50000
# [183]	eval-auc:0.50000	train-auc:0.50000
# [184]	eval-auc:0.50000	train-auc:0.50000
# [185]	eval-auc:0.50000	train-auc:0.50000
# [186]	eval-auc:0.50000	train-auc:0.50000
# [187]	eval-auc:0.50000	train-auc:0.50000
# [188]	eval-auc:0.50000	train-auc:0.50000
# [189]	eval-auc:0.50000	train-auc:0.50000
# [190]	eval-auc:0.50000	train-auc:0.50000
# [191]	eval-auc:0.50000	train-auc:0.50000
# [192]	eval-auc:0.50000	train-auc:0.50000
# [193]	eval-auc:0.50000	train-auc:0.50000
# [194]	eval-auc:0.50000	train-auc:0.50000
# [195]	eval-auc:0.50000	train-auc:0.50000
# [196]	eval-auc:0.50000	train-auc:0.50000
# [197]	eval-auc:0.50000	train-auc:0.50000
# [198]	eval-auc:0.50000	train-auc:0.50000
# [199]	eval-auc:0.50000	train-auc:0.50000
# [200]	eval-auc:0.50000	train-auc:0.50000
# [201]	eval-auc:0.50000	train-auc:0.50000
# [202]	eval-auc:0.50000	train-auc:0.50000
# [203]	eval-auc:0.50000	train-auc:0.50000
# [204]	eval-auc:0.50000	train-auc:0.50000
# [205]	eval-auc:0.50000	train-auc:0.50000
# [206]	eval-auc:0.50000	train-auc:0.50000
# [207]	eval-auc:0.50000	train-auc:0.50000
# [208]	eval-auc:0.50000	train-auc:0.50000
# [209]	eval-auc:0.50000	train-auc:0.50000
# [210]	eval-auc:0.50000	train-auc:0.50000
# [211]	eval-auc:0.50000	train-auc:0.50000
# [212]	eval-auc:0.50000	train-auc:0.50000
# [213]	eval-auc:0.50000	train-auc:0.50000
# [214]	eval-auc:0.50000	train-auc:0.50000
# [215]	eval-auc:0.50000	train-auc:0.50000
# [216]	eval-auc:0.50000	train-auc:0.50000
# [217]	eval-auc:0.50000	train-auc:0.50000
# [218]	eval-auc:0.50000	train-auc:0.50000
# [219]	eval-auc:0.50000	train-auc:0.50000
# [220]	eval-auc:0.50000	train-auc:0.50000
# [221]	eval-auc:0.50000	train-auc:0.50000
# [222]	eval-auc:0.50000	train-auc:0.50000
# [223]	eval-auc:0.50000	train-auc:0.50000
# [224]	eval-auc:0.50000	train-auc:0.50000
# [225]	eval-auc:0.50000	train-auc:0.50000
# [226]	eval-auc:0.50000	train-auc:0.50000
# [227]	eval-auc:0.50000	train-auc:0.50000
# [228]	eval-auc:0.50000	train-auc:0.50000
# [229]	eval-auc:0.50000	train-auc:0.50000
# [230]	eval-auc:0.50000	train-auc:0.50000
# [231]	eval-auc:0.50000	train-auc:0.50000
# [232]	eval-auc:0.50000	train-auc:0.50000
# [233]	eval-auc:0.50000	train-auc:0.50000
# [234]	eval-auc:0.50000	train-auc:0.50000
# [235]	eval-auc:0.50000	train-auc:0.50000
# [236]	eval-auc:0.50000	train-auc:0.50000
# [237]	eval-auc:0.50000	train-auc:0.50000
# [238]	eval-auc:0.50000	train-auc:0.50000
# [239]	eval-auc:0.50000	train-auc:0.50000
# [240]	eval-auc:0.50000	train-auc:0.50000
# [241]	eval-auc:0.50000	train-auc:0.50000
# [242]	eval-auc:0.50000	train-auc:0.50000
# [243]	eval-auc:0.50000	train-auc:0.50000
# [244]	eval-auc:0.50000	train-auc:0.50000
# [245]	eval-auc:0.50000	train-auc:0.50000
# [246]	eval-auc:0.50000	train-auc:0.50000
# [247]	eval-auc:0.50000	train-auc:0.50000
# [248]	eval-auc:0.50000	train-auc:0.50000
# [249]	eval-auc:0.50000	train-auc:0.50000
# [250]	eval-auc:0.50000	train-auc:0.50000
# [251]	eval-auc:0.50000	train-auc:0.50000
# [252]	eval-auc:0.50000	train-auc:0.50000
# [253]	eval-auc:0.50000	train-auc:0.50000
# [254]	eval-auc:0.50000	train-auc:0.50000
# [255]	eval-auc:0.50000	train-auc:0.50000
# [256]	eval-auc:0.50000	train-auc:0.50000
# [257]	eval-auc:0.50000	train-auc:0.50000
# [258]	eval-auc:0.50000	train-auc:0.50000
# [259]	eval-auc:0.50000	train-auc:0.50000
# [260]	eval-auc:0.50000	train-auc:0.50000
# [261]	eval-auc:0.50000	train-auc:0.50000
# [262]	eval-auc:0.50000	train-auc:0.50000
# [263]	eval-auc:0.50000	train-auc:0.50000
# [264]	eval-auc:0.50000	train-auc:0.50000
# [265]	eval-auc:0.50000	train-auc:0.50000
# [266]	eval-auc:0.50000	train-auc:0.50000
# [267]	eval-auc:0.50000	train-auc:0.50000
# [268]	eval-auc:0.50000	train-auc:0.50000
# [269]	eval-auc:0.50000	train-auc:0.50000
# [270]	eval-auc:0.50000	train-auc:0.50000
# [271]	eval-auc:0.50000	train-auc:0.50000
# [272]	eval-auc:0.50000	train-auc:0.50000
# [273]	eval-auc:0.50000	train-auc:0.50000
# [274]	eval-auc:0.50000	train-auc:0.50000
# [275]	eval-auc:0.50000	train-auc:0.50000
# [276]	eval-auc:0.50000	train-auc:0.50000
# [277]	eval-auc:0.50000	train-auc:0.50000
# [278]	eval-auc:0.50000	train-auc:0.50000
# [279]	eval-auc:0.50000	train-auc:0.50000
# [280]	eval-auc:0.50000	train-auc:0.50000
# [281]	eval-auc:0.50000	train-auc:0.50000
# [282]	eval-auc:0.50000	train-auc:0.50000
# [283]	eval-auc:0.50000	train-auc:0.50000
# [284]	eval-auc:0.50000	train-auc:0.50000
# [285]	eval-auc:0.50000	train-auc:0.50000
# [286]	eval-auc:0.50000	train-auc:0.50000
# [287]	eval-auc:0.50000	train-auc:0.50000
# [288]	eval-auc:0.50000	train-auc:0.50000
# [289]	eval-auc:0.50000	train-auc:0.50000
# [290]	eval-auc:0.50000	train-auc:0.50000
# [291]	eval-auc:0.50000	train-auc:0.50000
# [292]	eval-auc:0.50000	train-auc:0.50000
# [293]	eval-auc:0.50000	train-auc:0.50000
# [294]	eval-auc:0.50000	train-auc:0.50000
# [295]	eval-auc:0.50000	train-auc:0.50000
# [296]	eval-auc:0.50000	train-auc:0.50000
# [297]	eval-auc:0.50000	train-auc:0.50000
# [298]	eval-auc:0.50000	train-auc:0.50000
# [299]	eval-auc:0.50000	train-auc:0.50000
# [300]	eval-auc:0.50000	train-auc:0.50000
# [301]	eval-auc:0.50000	train-auc:0.50000
# [302]	eval-auc:0.50000	train-auc:0.50000
# [303]	eval-auc:0.50000	train-auc:0.50000
# [304]	eval-auc:0.50000	train-auc:0.50000
# [305]	eval-auc:0.50000	train-auc:0.50000
# [306]	eval-auc:0.50000	train-auc:0.50000
# [307]	eval-auc:0.50000	train-auc:0.50000
# [308]	eval-auc:0.50000	train-auc:0.50000
# [309]	eval-auc:0.50000	train-auc:0.50000
# [310]	eval-auc:0.50000	train-auc:0.50000
# [311]	eval-auc:0.50000	train-auc:0.50000
# [312]	eval-auc:0.50000	train-auc:0.50000
# [313]	eval-auc:0.50000	train-auc:0.50000
# [314]	eval-auc:0.50000	train-auc:0.50000
# [315]	eval-auc:0.50000	train-auc:0.50000
# [316]	eval-auc:0.50000	train-auc:0.50000
# [317]	eval-auc:0.50000	train-auc:0.50000
# [318]	eval-auc:0.50000	train-auc:0.50000
# [319]	eval-auc:0.50000	train-auc:0.50000
# [320]	eval-auc:0.50000	train-auc:0.50000
# [321]	eval-auc:0.50000	train-auc:0.50000
# [322]	eval-auc:0.50000	train-auc:0.50000
# [323]	eval-auc:0.50000	train-auc:0.50000
# [324]	eval-auc:0.50000	train-auc:0.50000
# [325]	eval-auc:0.50000	train-auc:0.50000
# [326]	eval-auc:0.50000	train-auc:0.50000
# [327]	eval-auc:0.50000	train-auc:0.50000
# [328]	eval-auc:0.50000	train-auc:0.50000
# [329]	eval-auc:0.50000	train-auc:0.50000
# [330]	eval-auc:0.50000	train-auc:0.50000
# [331]	eval-auc:0.50000	train-auc:0.50000
# [332]	eval-auc:0.50000	train-auc:0.50000
# [333]	eval-auc:0.50000	train-auc:0.50000
# [334]	eval-auc:0.50000	train-auc:0.50000
# [335]	eval-auc:0.50000	train-auc:0.50000
# [336]	eval-auc:0.50000	train-auc:0.50000
# [337]	eval-auc:0.50000	train-auc:0.50000
# [338]	eval-auc:0.50000	train-auc:0.50000
# [339]	eval-auc:0.50000	train-auc:0.50000
# [340]	eval-auc:0.50000	train-auc:0.50000
# [341]	eval-auc:0.50000	train-auc:0.50000
# [342]	eval-auc:0.50000	train-auc:0.50000
# [343]	eval-auc:0.50000	train-auc:0.50000
# [344]	eval-auc:0.50000	train-auc:0.50000
# [345]	eval-auc:0.50000	train-auc:0.50000
# [346]	eval-auc:0.50000	train-auc:0.50000
# [347]	eval-auc:0.50000	train-auc:0.50000
# [348]	eval-auc:0.50000	train-auc:0.50000
# [349]	eval-auc:0.50000	train-auc:0.50000
# [350]	eval-auc:0.50000	train-auc:0.50000
# [351]	eval-auc:0.50000	train-auc:0.50000
# [352]	eval-auc:0.50000	train-auc:0.50000
# [353]	eval-auc:0.50000	train-auc:0.50000
# [354]	eval-auc:0.50000	train-auc:0.50000
# [355]	eval-auc:0.50000	train-auc:0.50000
# [356]	eval-auc:0.50000	train-auc:0.50000
# [357]	eval-auc:0.50000	train-auc:0.50000
# [358]	eval-auc:0.50000	train-auc:0.50000
# [359]	eval-auc:0.50000	train-auc:0.50000
# [360]	eval-auc:0.50000	train-auc:0.50000
# [361]	eval-auc:0.50000	train-auc:0.50000
# [362]	eval-auc:0.50000	train-auc:0.50000
# [363]	eval-auc:0.50000	train-auc:0.50000
# [364]	eval-auc:0.50000	train-auc:0.50000
# [365]	eval-auc:0.50000	train-auc:0.50000
# [366]	eval-auc:0.50000	train-auc:0.50000
# [367]	eval-auc:0.50000	train-auc:0.50000
# [368]	eval-auc:0.50000	train-auc:0.50000
# [369]	eval-auc:0.50000	train-auc:0.50000
# [370]	eval-auc:0.50000	train-auc:0.50000
# [371]	eval-auc:0.50000	train-auc:0.50000
# [372]	eval-auc:0.50000	train-auc:0.50000
# [373]	eval-auc:0.50000	train-auc:0.50000
# [374]	eval-auc:0.50000	train-auc:0.50000
# [375]	eval-auc:0.50000	train-auc:0.50000
# [376]	eval-auc:0.50000	train-auc:0.50000
# [377]	eval-auc:0.50000	train-auc:0.50000
# [378]	eval-auc:0.50000	train-auc:0.50000
# [379]	eval-auc:0.50000	train-auc:0.50000
# [380]	eval-auc:0.50000	train-auc:0.50000
# [381]	eval-auc:0.50000	train-auc:0.50000
# [382]	eval-auc:0.50000	train-auc:0.50000
# [383]	eval-auc:0.50000	train-auc:0.50000
# [384]	eval-auc:0.50000	train-auc:0.50000
# [385]	eval-auc:0.50000	train-auc:0.50000
# [386]	eval-auc:0.50000	train-auc:0.50000
# [387]	eval-auc:0.50000	train-auc:0.50000
# [388]	eval-auc:0.50000	train-auc:0.50000
# [389]	eval-auc:0.50000	train-auc:0.50000
# [390]	eval-auc:0.50000	train-auc:0.50000
# [391]	eval-auc:0.50000	train-auc:0.50000
# [392]	eval-auc:0.50000	train-auc:0.50000
# [393]	eval-auc:0.50000	train-auc:0.50000
# [394]	eval-auc:0.50000	train-auc:0.50000
# [395]	eval-auc:0.50000	train-auc:0.50000
# [396]	eval-auc:0.50000	train-auc:0.50000
# [397]	eval-auc:0.50000	train-auc:0.50000
# [398]	eval-auc:0.50000	train-auc:0.50000
# [399]	eval-auc:0.50000	train-auc:0.50000
# [400]	eval-auc:0.50000	train-auc:0.50000
# [401]	eval-auc:0.50000	train-auc:0.50000
# [402]	eval-auc:0.50000	train-auc:0.50000
# [403]	eval-auc:0.50000	train-auc:0.50000
# [404]	eval-auc:0.50000	train-auc:0.50000
# [405]	eval-auc:0.50000	train-auc:0.50000
# [406]	eval-auc:0.50000	train-auc:0.50000
# [407]	eval-auc:0.50000	train-auc:0.50000
# [408]	eval-auc:0.50000	train-auc:0.50000
# [409]	eval-auc:0.50000	train-auc:0.50000
# [410]	eval-auc:0.50000	train-auc:0.50000
# [411]	eval-auc:0.50000	train-auc:0.50000
# [412]	eval-auc:0.50000	train-auc:0.50000
# [413]	eval-auc:0.50000	train-auc:0.50000
# [414]	eval-auc:0.50000	train-auc:0.50000
# [415]	eval-auc:0.50000	train-auc:0.50000
# [416]	eval-auc:0.50000	train-auc:0.50000
# [417]	eval-auc:0.50000	train-auc:0.50000
# [418]	eval-auc:0.50000	train-auc:0.50000
# [419]	eval-auc:0.50000	train-auc:0.50000
# [420]	eval-auc:0.50000	train-auc:0.50000
# [421]	eval-auc:0.50000	train-auc:0.50000
# [422]	eval-auc:0.50000	train-auc:0.50000
# [423]	eval-auc:0.50000	train-auc:0.50000
# [424]	eval-auc:0.50000	train-auc:0.50000
# [425]	eval-auc:0.50000	train-auc:0.50000
# [426]	eval-auc:0.50000	train-auc:0.50000
# [427]	eval-auc:0.50000	train-auc:0.50000
# [428]	eval-auc:0.50000	train-auc:0.50000
# [429]	eval-auc:0.50000	train-auc:0.50000
# [430]	eval-auc:0.50000	train-auc:0.50000
# [431]	eval-auc:0.50000	train-auc:0.50000
# [432]	eval-auc:0.50000	train-auc:0.50000
# [433]	eval-auc:0.50000	train-auc:0.50000
# [434]	eval-auc:0.50000	train-auc:0.50000
# [435]	eval-auc:0.50000	train-auc:0.50000
# [436]	eval-auc:0.50000	train-auc:0.50000
# [437]	eval-auc:0.50000	train-auc:0.50000
# [438]	eval-auc:0.50000	train-auc:0.50000
# [439]	eval-auc:0.50000	train-auc:0.50000
# [440]	eval-auc:0.50000	train-auc:0.50000
# [441]	eval-auc:0.50000	train-auc:0.50000
# [442]	eval-auc:0.50000	train-auc:0.50000
# [443]	eval-auc:0.50000	train-auc:0.50000
# [444]	eval-auc:0.50000	train-auc:0.50000
# [445]	eval-auc:0.50000	train-auc:0.50000
# [446]	eval-auc:0.50000	train-auc:0.50000
# [447]	eval-auc:0.50000	train-auc:0.50000
# [448]	eval-auc:0.50000	train-auc:0.50000
# [449]	eval-auc:0.50000	train-auc:0.50000
# [450]	eval-auc:0.50000	train-auc:0.50000
# [451]	eval-auc:0.50000	train-auc:0.50000
# [452]	eval-auc:0.50000	train-auc:0.50000
# [453]	eval-auc:0.50000	train-auc:0.50000
# [454]	eval-auc:0.50000	train-auc:0.50000
# [455]	eval-auc:0.50000	train-auc:0.50000
# [456]	eval-auc:0.50000	train-auc:0.50000
# [457]	eval-auc:0.50000	train-auc:0.50000
# [458]	eval-auc:0.50000	train-auc:0.50000
# [459]	eval-auc:0.50000	train-auc:0.50000
# [460]	eval-auc:0.50000	train-auc:0.50000
# [461]	eval-auc:0.50000	train-auc:0.50000
# [462]	eval-auc:0.50000	train-auc:0.50000
# [463]	eval-auc:0.50000	train-auc:0.50000
# [464]	eval-auc:0.50000	train-auc:0.50000
# [465]	eval-auc:0.50000	train-auc:0.50000
# [466]	eval-auc:0.50000	train-auc:0.50000
# [467]	eval-auc:0.50000	train-auc:0.50000
# [468]	eval-auc:0.50000	train-auc:0.50000
# [469]	eval-auc:0.50000	train-auc:0.50000
# [470]	eval-auc:0.50000	train-auc:0.50000
# [471]	eval-auc:0.50000	train-auc:0.50000
# [472]	eval-auc:0.50000	train-auc:0.50000
# [473]	eval-auc:0.50000	train-auc:0.50000
# [474]	eval-auc:0.50000	train-auc:0.50000
# [475]	eval-auc:0.50000	train-auc:0.50000
# [476]	eval-auc:0.50000	train-auc:0.50000
# [477]	eval-auc:0.50000	train-auc:0.50000
# [478]	eval-auc:0.50000	train-auc:0.50000
# [479]	eval-auc:0.50000	train-auc:0.50000
# [480]	eval-auc:0.50000	train-auc:0.50000
# [481]	eval-auc:0.50000	train-auc:0.50000
# [482]	eval-auc:0.50000	train-auc:0.50000
# [483]	eval-auc:0.50000	train-auc:0.50000
# [484]	eval-auc:0.50000	train-auc:0.50000
# [485]	eval-auc:0.50000	train-auc:0.50000
# [486]	eval-auc:0.50000	train-auc:0.50000
# [487]	eval-auc:0.50000	train-auc:0.50000
# [488]	eval-auc:0.50000	train-auc:0.50000
# [489]	eval-auc:0.50000	train-auc:0.50000
# [490]	eval-auc:0.50000	train-auc:0.50000
# [491]	eval-auc:0.50000	train-auc:0.50000
# [492]	eval-auc:0.50000	train-auc:0.50000
# [493]	eval-auc:0.50000	train-auc:0.50000
# [494]	eval-auc:0.50000	train-auc:0.50000
# [495]	eval-auc:0.50000	train-auc:0.50000
# [496]	eval-auc:0.50000	train-auc:0.50000
# [497]	eval-auc:0.50000	train-auc:0.50000
# [498]	eval-auc:0.50000	train-auc:0.50000
# [499]	eval-auc:0.50000	train-auc:0.50000
# [500]	eval-auc:0.50000	train-auc:0.50000
# [501]	eval-auc:0.50000	train-auc:0.50000
# [502]	eval-auc:0.50000	train-auc:0.50000
# [503]	eval-auc:0.50000	train-auc:0.50000
# [504]	eval-auc:0.60259	train-auc:0.77320
# [505]	eval-auc:0.60259	train-auc:0.77320
# [506]	eval-auc:0.60259	train-auc:0.77320
# [507]	eval-auc:0.60259	train-auc:0.77320
# [508]	eval-auc:0.60259	train-auc:0.77320
# [509]	eval-auc:0.60259	train-auc:0.77320
# [510]	eval-auc:0.60259	train-auc:0.77320
# [511]	eval-auc:0.60259	train-auc:0.77320
# [512]	eval-auc:0.60259	train-auc:0.77320
# [513]	eval-auc:0.58508	train-auc:0.87113
# [514]	eval-auc:0.59104	train-auc:0.87113
# [515]	eval-auc:0.57948	train-auc:0.87113
# [516]	eval-auc:0.60889	train-auc:0.87113
# [517]	eval-auc:0.57948	train-auc:0.87113
# [518]	eval-auc:0.57948	train-auc:0.87113
# [519]	eval-auc:0.58543	train-auc:0.87113
# [520]	eval-auc:0.58543	train-auc:0.87113
# [521]	eval-auc:0.59139	train-auc:0.87113
# [522]	eval-auc:0.56793	train-auc:0.87113
# [523]	eval-auc:0.56793	train-auc:0.87113
# [524]	eval-auc:0.56793	train-auc:0.87113
# [525]	eval-auc:0.57388	train-auc:0.87113
# [526]	eval-auc:0.57388	train-auc:0.87113
# [527]	eval-auc:0.57983	train-auc:0.87113
# [528]	eval-auc:0.56793	train-auc:0.87113
# [529]	eval-auc:0.57983	train-auc:0.87113
# [530]	eval-auc:0.57388	train-auc:0.87113
# [531]	eval-auc:0.57983	train-auc:0.87113
# [532]	eval-auc:0.57983	train-auc:0.88144
# [533]	eval-auc:0.57983	train-auc:0.90206
# [534]	eval-auc:0.57983	train-auc:0.90979
# [535]	eval-auc:0.57983	train-auc:0.90979
# [536]	eval-auc:0.57983	train-auc:0.90979
# [537]	eval-auc:0.57983	train-auc:0.90979
# [538]	eval-auc:0.57983	train-auc:0.90979
# [539]	eval-auc:0.57983	train-auc:0.90979
# [540]	eval-auc:0.58578	train-auc:0.90979
# [541]	eval-auc:0.58578	train-auc:0.90979
# [542]	eval-auc:0.56828	train-auc:0.90979
# [543]	eval-auc:0.59769	train-auc:0.90979
# [544]	eval-auc:0.56828	train-auc:0.90979
# [545]	eval-auc:0.56232	train-auc:0.90979
# [546]	eval-auc:0.56828	train-auc:0.91237
# [547]	eval-auc:0.56828	train-auc:0.92010
# [548]	eval-auc:0.56828	train-auc:0.93041
# [549]	eval-auc:0.56828	train-auc:0.93557
# [550]	eval-auc:0.56828	train-auc:0.93557
# [551]	eval-auc:0.57423	train-auc:0.93557
# [552]	eval-auc:0.57423	train-auc:0.93557
# [553]	eval-auc:0.54482	train-auc:0.93557
# [554]	eval-auc:0.54482	train-auc:0.93557
# [555]	eval-auc:0.48599	train-auc:0.93557
# [556]	eval-auc:0.48599	train-auc:0.93557
# [557]	eval-auc:0.48599	train-auc:0.94330
# [558]	eval-auc:0.48599	train-auc:0.95361
# [559]	eval-auc:0.45658	train-auc:0.95619
# [560]	eval-auc:0.46253	train-auc:0.95619
# [561]	eval-auc:0.46253	train-auc:0.95619
# [562]	eval-auc:0.46253	train-auc:0.95619
# [563]	eval-auc:0.45658	train-auc:0.95619
# [564]	eval-auc:0.46849	train-auc:0.95619
# [565]	eval-auc:0.46253	train-auc:0.95619
# [566]	eval-auc:0.46849	train-auc:0.95619
# [567]	eval-auc:0.46849	train-auc:0.95619
# [568]	eval-auc:0.46849	train-auc:0.95619
# [569]	eval-auc:0.48039	train-auc:0.95619
# [570]	eval-auc:0.48039	train-auc:0.95619
# [571]	eval-auc:0.48039	train-auc:0.95619
# [572]	eval-auc:0.48039	train-auc:0.95619
# [573]	eval-auc:0.48635	train-auc:0.95619
# [574]	eval-auc:0.49230	train-auc:0.95619
# [575]	eval-auc:0.49230	train-auc:0.95619
# [576]	eval-auc:0.46288	train-auc:0.95619
# [577]	eval-auc:0.46288	train-auc:0.95619
# [578]	eval-auc:0.46884	train-auc:0.95619
# [579]	eval-auc:0.46884	train-auc:0.95619
# [580]	eval-auc:0.46884	train-auc:0.95619
# [581]	eval-auc:0.46884	train-auc:0.95619
# [582]	eval-auc:0.46884	train-auc:0.95619
# [583]	eval-auc:0.46884	train-auc:0.95619
# [584]	eval-auc:0.46884	train-auc:0.95619
# [585]	eval-auc:0.46884	train-auc:0.95619
# [586]	eval-auc:0.43943	train-auc:0.95619
# [587]	eval-auc:0.43943	train-auc:0.95619
# [588]	eval-auc:0.43943	train-auc:0.95619
# [589]	eval-auc:0.46884	train-auc:0.95619
# [590]	eval-auc:0.46884	train-auc:0.95619
# [591]	eval-auc:0.46884	train-auc:0.95619
# [592]	eval-auc:0.46884	train-auc:0.95619
# [593]	eval-auc:0.46884	train-auc:0.95619
# [594]	eval-auc:0.43943	train-auc:0.95619
# [595]	eval-auc:0.43943	train-auc:0.95619
# [596]	eval-auc:0.44538	train-auc:0.95619
# [597]	eval-auc:0.44538	train-auc:0.95619
# [598]	eval-auc:0.44538	train-auc:0.95619
# [599]	eval-auc:0.44538	train-auc:0.95619
# [600]	eval-auc:0.44538	train-auc:0.95619
# [601]	eval-auc:0.44538	train-auc:0.95619
# [602]	eval-auc:0.41597	train-auc:0.95619
# [603]	eval-auc:0.44538	train-auc:0.95619
# [604]	eval-auc:0.41597	train-auc:0.95619
# [605]	eval-auc:0.44538	train-auc:0.95619
# [606]	eval-auc:0.41597	train-auc:0.95619
# [607]	eval-auc:0.41597	train-auc:0.95619
# [608]	eval-auc:0.41597	train-auc:0.95619
# [609]	eval-auc:0.41597	train-auc:0.95619
# [610]	eval-auc:0.41597	train-auc:0.95619
# [611]	eval-auc:0.41597	train-auc:0.95619
# [612]	eval-auc:0.41597	train-auc:0.95619
# [613]	eval-auc:0.41597	train-auc:0.95619
# [614]	eval-auc:0.41597	train-auc:0.95619
# [615]	eval-auc:0.41597	train-auc:0.95619
# [616]	eval-auc:0.41597	train-auc:0.95619
# [617]	eval-auc:0.41597	train-auc:0.95619
# [618]	eval-auc:0.41597	train-auc:0.95619
# [619]	eval-auc:0.41597	train-auc:0.95619
# [620]	eval-auc:0.41597	train-auc:0.95619
# [621]	eval-auc:0.41597	train-auc:0.95619
# [622]	eval-auc:0.41597	train-auc:0.95619
# [623]	eval-auc:0.41597	train-auc:0.95619
# [624]	eval-auc:0.41597	train-auc:0.95619
# [625]	eval-auc:0.41597	train-auc:0.95619
# [626]	eval-auc:0.41597	train-auc:0.95619
# [627]	eval-auc:0.41597	train-auc:0.95619
# [628]	eval-auc:0.41597	train-auc:0.95619
# [629]	eval-auc:0.41597	train-auc:0.95876
# [630]	eval-auc:0.41597	train-auc:0.95876
# [631]	eval-auc:0.41597	train-auc:0.96392
# [632]	eval-auc:0.41597	train-auc:0.96392
# [633]	eval-auc:0.41597	train-auc:0.96907
# [634]	eval-auc:0.41597	train-auc:0.97165
# [635]	eval-auc:0.41597	train-auc:0.97165
# [636]	eval-auc:0.41597	train-auc:0.97165
# [637]	eval-auc:0.41597	train-auc:0.97165
# [638]	eval-auc:0.41597	train-auc:0.97165
# [639]	eval-auc:0.41597	train-auc:0.97165
# [640]	eval-auc:0.41597	train-auc:0.97165
# [641]	eval-auc:0.41597	train-auc:0.97165
# [642]	eval-auc:0.41597	train-auc:0.97165
# [643]	eval-auc:0.41597	train-auc:0.97165
# [644]	eval-auc:0.41597	train-auc:0.97165
# [645]	eval-auc:0.41597	train-auc:0.97165
# [646]	eval-auc:0.41597	train-auc:0.97165
# [647]	eval-auc:0.41597	train-auc:0.97165
# [648]	eval-auc:0.41597	train-auc:0.97165
# [649]	eval-auc:0.41597	train-auc:0.97165
# [650]	eval-auc:0.41597	train-auc:0.97165
# [651]	eval-auc:0.41597	train-auc:0.97165
# [652]	eval-auc:0.41597	train-auc:0.97165
# [653]	eval-auc:0.41597	train-auc:0.97165
# [654]	eval-auc:0.41597	train-auc:0.97165
# [655]	eval-auc:0.41597	train-auc:0.97165
# [656]	eval-auc:0.42192	train-auc:0.97165
# [657]	eval-auc:0.42192	train-auc:0.97165
# [658]	eval-auc:0.42192	train-auc:0.97165
# [659]	eval-auc:0.42192	train-auc:0.97165
# [660]	eval-auc:0.42192	train-auc:0.97165
# [661]	eval-auc:0.42192	train-auc:0.97165
# [662]	eval-auc:0.42192	train-auc:0.97165
# [663]	eval-auc:0.42192	train-auc:0.97165
# [664]	eval-auc:0.42192	train-auc:0.97165
# [665]	eval-auc:0.42192	train-auc:0.97165
# [666]	eval-auc:0.42192	train-auc:0.97165
# [667]	eval-auc:0.42192	train-auc:0.97165
# [668]	eval-auc:0.42192	train-auc:0.97165
# [669]	eval-auc:0.42192	train-auc:0.97165
# [670]	eval-auc:0.42192	train-auc:0.97165
# [671]	eval-auc:0.42192	train-auc:0.97165
# [672]	eval-auc:0.42192	train-auc:0.97165
# [673]	eval-auc:0.42192	train-auc:0.97680
# [674]	eval-auc:0.42192	train-auc:0.97680
# [675]	eval-auc:0.42192	train-auc:0.98196
# [676]	eval-auc:0.42192	train-auc:0.98969
# [677]	eval-auc:0.42192	train-auc:0.98969
# [678]	eval-auc:0.42192	train-auc:0.98969
# [679]	eval-auc:0.42192	train-auc:0.98969
# [680]	eval-auc:0.42192	train-auc:0.99227
# [681]	eval-auc:0.42192	train-auc:0.99227
# [682]	eval-auc:0.42192	train-auc:0.99227
# [683]	eval-auc:0.42192	train-auc:0.99227
# [684]	eval-auc:0.42192	train-auc:0.99227
# [685]	eval-auc:0.42192	train-auc:0.99227
# [686]	eval-auc:0.42192	train-auc:0.99227
# [687]	eval-auc:0.42192	train-auc:0.99227
# [688]	eval-auc:0.42192	train-auc:0.99227
# [689]	eval-auc:0.42192	train-auc:0.99227
# [690]	eval-auc:0.42192	train-auc:0.99227
# [691]	eval-auc:0.42192	train-auc:0.99227
# [692]	eval-auc:0.42192	train-auc:0.99227
# [693]	eval-auc:0.42192	train-auc:0.99227
# [694]	eval-auc:0.42192	train-auc:0.99227
# [695]	eval-auc:0.42192	train-auc:0.99227
# [696]	eval-auc:0.42192	train-auc:0.99227
# [697]	eval-auc:0.42192	train-auc:0.99227
# [698]	eval-auc:0.42192	train-auc:0.99227
# [699]	eval-auc:0.42192	train-auc:0.99227
# [700]	eval-auc:0.42192	train-auc:0.99227
# [701]	eval-auc:0.42192	train-auc:0.99227
# [702]	eval-auc:0.42192	train-auc:0.99227
# [703]	eval-auc:0.42192	train-auc:0.99227
# [704]	eval-auc:0.42192	train-auc:0.99227
# [705]	eval-auc:0.42192	train-auc:0.99227
# [706]	eval-auc:0.42192	train-auc:0.99227
# [707]	eval-auc:0.42192	train-auc:0.99227
# [708]	eval-auc:0.42192	train-auc:0.99227
# [709]	eval-auc:0.42192	train-auc:0.99227
# [710]	eval-auc:0.42192	train-auc:0.99227
# [711]	eval-auc:0.42192	train-auc:0.99227
# [712]	eval-auc:0.42192	train-auc:0.99227
# [713]	eval-auc:0.42192	train-auc:0.99227
# [714]	eval-auc:0.42192	train-auc:0.99227
# [715]	eval-auc:0.42192	train-auc:0.99227
# [716]	eval-auc:0.42192	train-auc:0.99227
# [717]	eval-auc:0.42192	train-auc:0.99227
# [718]	eval-auc:0.42192	train-auc:0.99227
# [719]	eval-auc:0.42192	train-auc:0.99227
# [720]	eval-auc:0.42192	train-auc:0.99227
# [721]	eval-auc:0.42192	train-auc:0.99227
# [722]	eval-auc:0.42192	train-auc:0.99227
# [723]	eval-auc:0.42192	train-auc:0.99227
# [724]	eval-auc:0.42192	train-auc:0.99227
# [725]	eval-auc:0.42192	train-auc:0.99227
# [726]	eval-auc:0.42192	train-auc:0.99227
# [727]	eval-auc:0.42192	train-auc:0.99227
# [728]	eval-auc:0.42192	train-auc:0.99227
# [729]	eval-auc:0.42192	train-auc:0.99227
# [730]	eval-auc:0.42192	train-auc:0.99227
# [731]	eval-auc:0.42192	train-auc:0.99227
# [732]	eval-auc:0.42192	train-auc:0.99227
# [733]	eval-auc:0.42192	train-auc:0.99227
# [734]	eval-auc:0.42192	train-auc:0.99227
# [735]	eval-auc:0.42192	train-auc:0.99227
# [736]	eval-auc:0.42787	train-auc:0.99227
# [737]	eval-auc:0.42787	train-auc:0.99227
# [738]	eval-auc:0.42787	train-auc:0.99227
# [739]	eval-auc:0.42787	train-auc:0.99227
# [740]	eval-auc:0.42787	train-auc:0.99227
# [741]	eval-auc:0.42787	train-auc:0.99227
# [742]	eval-auc:0.42787	train-auc:0.99227
# [743]	eval-auc:0.42787	train-auc:0.99227
# [744]	eval-auc:0.43382	train-auc:0.99227
# [745]	eval-auc:0.43382	train-auc:0.99227
# [746]	eval-auc:0.43382	train-auc:0.99227
# [747]	eval-auc:0.43382	train-auc:0.99227
# [748]	eval-auc:0.43382	train-auc:0.99227
# [749]	eval-auc:0.43382	train-auc:0.99227
# [750]	eval-auc:0.43382	train-auc:0.99227
# [751]	eval-auc:0.43382	train-auc:0.99227
# [752]	eval-auc:0.43382	train-auc:0.99227
# [753]	eval-auc:0.43382	train-auc:0.99227
# [754]	eval-auc:0.43382	train-auc:0.99227
# [755]	eval-auc:0.43382	train-auc:0.99227
# [756]	eval-auc:0.43382	train-auc:0.99227
# [757]	eval-auc:0.43382	train-auc:0.99227
# [758]	eval-auc:0.43382	train-auc:0.99227
# [759]	eval-auc:0.43382	train-auc:0.99227
# [760]	eval-auc:0.43382	train-auc:0.99227
# [761]	eval-auc:0.43382	train-auc:0.99227
# [762]	eval-auc:0.43382	train-auc:0.99227
# [763]	eval-auc:0.43382	train-auc:0.99227
# [764]	eval-auc:0.43382	train-auc:0.99484
# [765]	eval-auc:0.43382	train-auc:0.99742
# [766]	eval-auc:0.43382	train-auc:1.00000
# [767]	eval-auc:0.43382	train-auc:1.00000
# [768]	eval-auc:0.43382	train-auc:1.00000
# [769]	eval-auc:0.43382	train-auc:1.00000
# [770]	eval-auc:0.43382	train-auc:1.00000
# [771]	eval-auc:0.43382	train-auc:1.00000
# [772]	eval-auc:0.43382	train-auc:1.00000
# [773]	eval-auc:0.43382	train-auc:1.00000
# [774]	eval-auc:0.43382	train-auc:1.00000
# [775]	eval-auc:0.43382	train-auc:1.00000
# [776]	eval-auc:0.43382	train-auc:1.00000
# [777]	eval-auc:0.43382	train-auc:1.00000
# [778]	eval-auc:0.43382	train-auc:1.00000
# [779]	eval-auc:0.43382	train-auc:1.00000
# [780]	eval-auc:0.43382	train-auc:1.00000
# [781]	eval-auc:0.43382	train-auc:1.00000
# [782]	eval-auc:0.43382	train-auc:1.00000
# [783]	eval-auc:0.43382	train-auc:1.00000
# [784]	eval-auc:0.43382	train-auc:1.00000
# [785]	eval-auc:0.43382	train-auc:1.00000
# [786]	eval-auc:0.43382	train-auc:1.00000
# [787]	eval-auc:0.43382	train-auc:1.00000
# [788]	eval-auc:0.43382	train-auc:1.00000
# [789]	eval-auc:0.43382	train-auc:1.00000
# [790]	eval-auc:0.43382	train-auc:1.00000
# [791]	eval-auc:0.43382	train-auc:1.00000
# [792]	eval-auc:0.43382	train-auc:1.00000
# [793]	eval-auc:0.43382	train-auc:1.00000
# [794]	eval-auc:0.43382	train-auc:1.00000
# [795]	eval-auc:0.43382	train-auc:1.00000
# [796]	eval-auc:0.43382	train-auc:1.00000
# [797]	eval-auc:0.43382	train-auc:1.00000
# [798]	eval-auc:0.43382	train-auc:1.00000
# [799]	eval-auc:0.43382	train-auc:1.00000
# [0]	eval-auc:0.50000	train-auc:0.50000
# [1]	eval-auc:0.50000	train-auc:0.50000
# [2]	eval-auc:0.50000	train-auc:0.50000
# [3]	eval-auc:0.50000	train-auc:0.50000
# [4]	eval-auc:0.50000	train-auc:0.50000
# [5]	eval-auc:0.50000	train-auc:0.50000
# [6]	eval-auc:0.50000	train-auc:0.50000
# [7]	eval-auc:0.50000	train-auc:0.50000
# [8]	eval-auc:0.50000	train-auc:0.50000
# [9]	eval-auc:0.50000	train-auc:0.50000
# [10]	eval-auc:0.50000	train-auc:0.50000
# [11]	eval-auc:0.50000	train-auc:0.50000
# [12]	eval-auc:0.50000	train-auc:0.50000
# [13]	eval-auc:0.50000	train-auc:0.50000
# [14]	eval-auc:0.50000	train-auc:0.50000
# [15]	eval-auc:0.50000	train-auc:0.50000
# [16]	eval-auc:0.50000	train-auc:0.50000
# [17]	eval-auc:0.50000	train-auc:0.50000
# [18]	eval-auc:0.50000	train-auc:0.50000
# [19]	eval-auc:0.50000	train-auc:0.50000
# [20]	eval-auc:0.50000	train-auc:0.50000
# [21]	eval-auc:0.50000	train-auc:0.50000
# [22]	eval-auc:0.50000	train-auc:0.50000
# [23]	eval-auc:0.50000	train-auc:0.50000
# [24]	eval-auc:0.50000	train-auc:0.50000
# [25]	eval-auc:0.50000	train-auc:0.50000
# [26]	eval-auc:0.50000	train-auc:0.50000
# [27]	eval-auc:0.50000	train-auc:0.50000
# [28]	eval-auc:0.50000	train-auc:0.50000
# [29]	eval-auc:0.50000	train-auc:0.50000
# [30]	eval-auc:0.50000	train-auc:0.50000
# [31]	eval-auc:0.50000	train-auc:0.50000
# [32]	eval-auc:0.50000	train-auc:0.50000
# [33]	eval-auc:0.50000	train-auc:0.50000
# [34]	eval-auc:0.50000	train-auc:0.50000
# [35]	eval-auc:0.50000	train-auc:0.50000
# [36]	eval-auc:0.50000	train-auc:0.50000
# [37]	eval-auc:0.50000	train-auc:0.50000
# [38]	eval-auc:0.50000	train-auc:0.50000
# [39]	eval-auc:0.50000	train-auc:0.50000
# [40]	eval-auc:0.50000	train-auc:0.50000
# [41]	eval-auc:0.50000	train-auc:0.50000
# [42]	eval-auc:0.50000	train-auc:0.50000
# [43]	eval-auc:0.50000	train-auc:0.50000
# [44]	eval-auc:0.50000	train-auc:0.50000
# [45]	eval-auc:0.50000	train-auc:0.50000
# [46]	eval-auc:0.50000	train-auc:0.50000
# [47]	eval-auc:0.50000	train-auc:0.50000
# [48]	eval-auc:0.50000	train-auc:0.50000
# [49]	eval-auc:0.50000	train-auc:0.50000
# [50]	eval-auc:0.50000	train-auc:0.50000
# [51]	eval-auc:0.50000	train-auc:0.50000
# [52]	eval-auc:0.50000	train-auc:0.50000
# [53]	eval-auc:0.50000	train-auc:0.50000
# [54]	eval-auc:0.50000	train-auc:0.50000
# [55]	eval-auc:0.50000	train-auc:0.50000
# [56]	eval-auc:0.50000	train-auc:0.50000
# [57]	eval-auc:0.50000	train-auc:0.50000
# [58]	eval-auc:0.50000	train-auc:0.50000
# [59]	eval-auc:0.50000	train-auc:0.50000
# [60]	eval-auc:0.50000	train-auc:0.50000
# [61]	eval-auc:0.50000	train-auc:0.50000
# [62]	eval-auc:0.50000	train-auc:0.50000
# [63]	eval-auc:0.50000	train-auc:0.50000
# [64]	eval-auc:0.50000	train-auc:0.50000
# [65]	eval-auc:0.50000	train-auc:0.50000
# [66]	eval-auc:0.50000	train-auc:0.50000
# [67]	eval-auc:0.50000	train-auc:0.50000
# [68]	eval-auc:0.50000	train-auc:0.50000
# [69]	eval-auc:0.50000	train-auc:0.50000
# [70]	eval-auc:0.50000	train-auc:0.50000
# [71]	eval-auc:0.50000	train-auc:0.50000
# [72]	eval-auc:0.50000	train-auc:0.50000
# [73]	eval-auc:0.50000	train-auc:0.50000
# [74]	eval-auc:0.50000	train-auc:0.50000
# [75]	eval-auc:0.50000	train-auc:0.50000
# [76]	eval-auc:0.50000	train-auc:0.50000
# [77]	eval-auc:0.50000	train-auc:0.50000
# [78]	eval-auc:0.50000	train-auc:0.50000
# [79]	eval-auc:0.50000	train-auc:0.50000
# [80]	eval-auc:0.50000	train-auc:0.50000
# [81]	eval-auc:0.50000	train-auc:0.50000
# [82]	eval-auc:0.50000	train-auc:0.50000
# [83]	eval-auc:0.50000	train-auc:0.50000
# [84]	eval-auc:0.50000	train-auc:0.50000
# [85]	eval-auc:0.50000	train-auc:0.50000
# [86]	eval-auc:0.50000	train-auc:0.50000
# [87]	eval-auc:0.50000	train-auc:0.50000
# [88]	eval-auc:0.50000	train-auc:0.50000
# [89]	eval-auc:0.50000	train-auc:0.50000
# [90]	eval-auc:0.50000	train-auc:0.50000
# [91]	eval-auc:0.50000	train-auc:0.50000
# [92]	eval-auc:0.50000	train-auc:0.50000
# [93]	eval-auc:0.50000	train-auc:0.50000
# [94]	eval-auc:0.50000	train-auc:0.50000
# [95]	eval-auc:0.50000	train-auc:0.50000
# [96]	eval-auc:0.50000	train-auc:0.50000
# [97]	eval-auc:0.50000	train-auc:0.50000
# [98]	eval-auc:0.50000	train-auc:0.50000
# [99]	eval-auc:0.50000	train-auc:0.50000
# [100]	eval-auc:0.50000	train-auc:0.50000
# [101]	eval-auc:0.50000	train-auc:0.50000
# [102]	eval-auc:0.50000	train-auc:0.50000
# [103]	eval-auc:0.50000	train-auc:0.50000
# [104]	eval-auc:0.50000	train-auc:0.50000
# [105]	eval-auc:0.50000	train-auc:0.50000
# [106]	eval-auc:0.50000	train-auc:0.50000
# [107]	eval-auc:0.50000	train-auc:0.50000
# [108]	eval-auc:0.50000	train-auc:0.50000
# [109]	eval-auc:0.50000	train-auc:0.50000
# [110]	eval-auc:0.50000	train-auc:0.50000
# [111]	eval-auc:0.50000	train-auc:0.50000
# [112]	eval-auc:0.50000	train-auc:0.50000
# [113]	eval-auc:0.50000	train-auc:0.50000
# [114]	eval-auc:0.50000	train-auc:0.50000
# [115]	eval-auc:0.50000	train-auc:0.50000
# [116]	eval-auc:0.50000	train-auc:0.50000
# [117]	eval-auc:0.50000	train-auc:0.50000
# [118]	eval-auc:0.50000	train-auc:0.50000
# [119]	eval-auc:0.50000	train-auc:0.50000
# [120]	eval-auc:0.50000	train-auc:0.50000
# [121]	eval-auc:0.50000	train-auc:0.50000
# [122]	eval-auc:0.50000	train-auc:0.50000
# [123]	eval-auc:0.50000	train-auc:0.50000
# [124]	eval-auc:0.50000	train-auc:0.50000
# [125]	eval-auc:0.50000	train-auc:0.50000
# [126]	eval-auc:0.50000	train-auc:0.50000
# [127]	eval-auc:0.50000	train-auc:0.50000
# [128]	eval-auc:0.50000	train-auc:0.50000
# [129]	eval-auc:0.50000	train-auc:0.50000
# [130]	eval-auc:0.50000	train-auc:0.50000
# [131]	eval-auc:0.50000	train-auc:0.50000
# [132]	eval-auc:0.50000	train-auc:0.50000
# [133]	eval-auc:0.50000	train-auc:0.50000
# [134]	eval-auc:0.50000	train-auc:0.50000
# [135]	eval-auc:0.50000	train-auc:0.50000
# [136]	eval-auc:0.50000	train-auc:0.50000
# [137]	eval-auc:0.50000	train-auc:0.50000
# [138]	eval-auc:0.50000	train-auc:0.50000
# [139]	eval-auc:0.50000	train-auc:0.50000
# [140]	eval-auc:0.50000	train-auc:0.50000
# [141]	eval-auc:0.50000	train-auc:0.50000
# [142]	eval-auc:0.50000	train-auc:0.50000
# [143]	eval-auc:0.50000	train-auc:0.50000
# [144]	eval-auc:0.50000	train-auc:0.50000
# [145]	eval-auc:0.50000	train-auc:0.50000
# [146]	eval-auc:0.50000	train-auc:0.50000
# [147]	eval-auc:0.50000	train-auc:0.50000
# [148]	eval-auc:0.50000	train-auc:0.50000
# [149]	eval-auc:0.50000	train-auc:0.50000
# [150]	eval-auc:0.50000	train-auc:0.50000
# [151]	eval-auc:0.50000	train-auc:0.50000
# [152]	eval-auc:0.50000	train-auc:0.50000
# [153]	eval-auc:0.50000	train-auc:0.50000
# [154]	eval-auc:0.50000	train-auc:0.50000
# [155]	eval-auc:0.50000	train-auc:0.50000
# [156]	eval-auc:0.50000	train-auc:0.50000
# [157]	eval-auc:0.50000	train-auc:0.50000
# [158]	eval-auc:0.50000	train-auc:0.50000
# [159]	eval-auc:0.50000	train-auc:0.50000
# [160]	eval-auc:0.50000	train-auc:0.50000
# [161]	eval-auc:0.50000	train-auc:0.50000
# [162]	eval-auc:0.50000	train-auc:0.50000
# [163]	eval-auc:0.50000	train-auc:0.50000
# [164]	eval-auc:0.50000	train-auc:0.50000
# [165]	eval-auc:0.50000	train-auc:0.50000
# [166]	eval-auc:0.50000	train-auc:0.50000
# [167]	eval-auc:0.50000	train-auc:0.50000
# [168]	eval-auc:0.50000	train-auc:0.50000
# [169]	eval-auc:0.50000	train-auc:0.50000
# [170]	eval-auc:0.50000	train-auc:0.50000
# [171]	eval-auc:0.50000	train-auc:0.50000
# [172]	eval-auc:0.50000	train-auc:0.50000
# [173]	eval-auc:0.50000	train-auc:0.50000
# [174]	eval-auc:0.50000	train-auc:0.50000
# [175]	eval-auc:0.50000	train-auc:0.50000
# [176]	eval-auc:0.50000	train-auc:0.50000
# [177]	eval-auc:0.50000	train-auc:0.50000
# [178]	eval-auc:0.50000	train-auc:0.50000
# [179]	eval-auc:0.50000	train-auc:0.50000
# [180]	eval-auc:0.50000	train-auc:0.50000
# [181]	eval-auc:0.50000	train-auc:0.50000
# [182]	eval-auc:0.50000	train-auc:0.50000
# [183]	eval-auc:0.50000	train-auc:0.50000
# [184]	eval-auc:0.50000	train-auc:0.50000
# [185]	eval-auc:0.50000	train-auc:0.50000
# [186]	eval-auc:0.50000	train-auc:0.50000
# [187]	eval-auc:0.50000	train-auc:0.50000
# [188]	eval-auc:0.50000	train-auc:0.50000
# [189]	eval-auc:0.50000	train-auc:0.50000
# [190]	eval-auc:0.50000	train-auc:0.50000
# [191]	eval-auc:0.50000	train-auc:0.50000
# [192]	eval-auc:0.50000	train-auc:0.50000
# [193]	eval-auc:0.50000	train-auc:0.50000
# [194]	eval-auc:0.50000	train-auc:0.50000
# [195]	eval-auc:0.50000	train-auc:0.50000
# [196]	eval-auc:0.50000	train-auc:0.50000
# [197]	eval-auc:0.50000	train-auc:0.50000
# [198]	eval-auc:0.50000	train-auc:0.50000
# [199]	eval-auc:0.50000	train-auc:0.50000
# [200]	eval-auc:0.50000	train-auc:0.50000
# [201]	eval-auc:0.50000	train-auc:0.50000
# [202]	eval-auc:0.50000	train-auc:0.50000
# [203]	eval-auc:0.50000	train-auc:0.50000
# [204]	eval-auc:0.50000	train-auc:0.50000
# [205]	eval-auc:0.50000	train-auc:0.50000
# [206]	eval-auc:0.50000	train-auc:0.50000
# [207]	eval-auc:0.50000	train-auc:0.50000
# [208]	eval-auc:0.50000	train-auc:0.50000
# [209]	eval-auc:0.50000	train-auc:0.50000
# [210]	eval-auc:0.50000	train-auc:0.50000
# [211]	eval-auc:0.50000	train-auc:0.50000
# [212]	eval-auc:0.50000	train-auc:0.50000
# [213]	eval-auc:0.50000	train-auc:0.50000
# [214]	eval-auc:0.50000	train-auc:0.50000
# [215]	eval-auc:0.50000	train-auc:0.50000
# [216]	eval-auc:0.50000	train-auc:0.50000
# [217]	eval-auc:0.50000	train-auc:0.50000
# [218]	eval-auc:0.50000	train-auc:0.50000
# [219]	eval-auc:0.50000	train-auc:0.50000
# [220]	eval-auc:0.50000	train-auc:0.50000
# [221]	eval-auc:0.50000	train-auc:0.50000
# [222]	eval-auc:0.50000	train-auc:0.50000
# [223]	eval-auc:0.50000	train-auc:0.50000
# [224]	eval-auc:0.50000	train-auc:0.50000
# [225]	eval-auc:0.50000	train-auc:0.50000
# [226]	eval-auc:0.50000	train-auc:0.50000
# [227]	eval-auc:0.50000	train-auc:0.50000
# [228]	eval-auc:0.50000	train-auc:0.50000
# [229]	eval-auc:0.50000	train-auc:0.50000
# [230]	eval-auc:0.50000	train-auc:0.50000
# [231]	eval-auc:0.50000	train-auc:0.50000
# [232]	eval-auc:0.50000	train-auc:0.50000
# [233]	eval-auc:0.50000	train-auc:0.50000
# [234]	eval-auc:0.50000	train-auc:0.50000
# [235]	eval-auc:0.50000	train-auc:0.50000
# [236]	eval-auc:0.50000	train-auc:0.50000
# [237]	eval-auc:0.50000	train-auc:0.50000
# [238]	eval-auc:0.50000	train-auc:0.50000
# [239]	eval-auc:0.50000	train-auc:0.50000
# [240]	eval-auc:0.50000	train-auc:0.50000
# [241]	eval-auc:0.50000	train-auc:0.50000
# [242]	eval-auc:0.50000	train-auc:0.50000
# [243]	eval-auc:0.50000	train-auc:0.50000
# [244]	eval-auc:0.50000	train-auc:0.50000
# [245]	eval-auc:0.50000	train-auc:0.50000
# [246]	eval-auc:0.50000	train-auc:0.50000
# [247]	eval-auc:0.50000	train-auc:0.50000
# [248]	eval-auc:0.50000	train-auc:0.50000
# [249]	eval-auc:0.50000	train-auc:0.50000
# [250]	eval-auc:0.50000	train-auc:0.50000
# [251]	eval-auc:0.50000	train-auc:0.50000
# [252]	eval-auc:0.50000	train-auc:0.50000
# [253]	eval-auc:0.50000	train-auc:0.50000
# [254]	eval-auc:0.50000	train-auc:0.50000
# [255]	eval-auc:0.50000	train-auc:0.50000
# [256]	eval-auc:0.50000	train-auc:0.50000
# [257]	eval-auc:0.50000	train-auc:0.50000
# [258]	eval-auc:0.50000	train-auc:0.50000
# [259]	eval-auc:0.50000	train-auc:0.50000
# [260]	eval-auc:0.50000	train-auc:0.50000
# [261]	eval-auc:0.50000	train-auc:0.50000
# [262]	eval-auc:0.50000	train-auc:0.50000
# [263]	eval-auc:0.50000	train-auc:0.50000
# [264]	eval-auc:0.50000	train-auc:0.50000
# [265]	eval-auc:0.50000	train-auc:0.50000
# [266]	eval-auc:0.50000	train-auc:0.50000
# [267]	eval-auc:0.50000	train-auc:0.50000
# [268]	eval-auc:0.50000	train-auc:0.50000
# [269]	eval-auc:0.50000	train-auc:0.50000
# [270]	eval-auc:0.50000	train-auc:0.50000
# [271]	eval-auc:0.50000	train-auc:0.50000
# [272]	eval-auc:0.50000	train-auc:0.50000
# [273]	eval-auc:0.50000	train-auc:0.50000
# [274]	eval-auc:0.50000	train-auc:0.50000
# [275]	eval-auc:0.50000	train-auc:0.50000
# [276]	eval-auc:0.50000	train-auc:0.50000
# [277]	eval-auc:0.50000	train-auc:0.50000
# [278]	eval-auc:0.50000	train-auc:0.50000
# [279]	eval-auc:0.50000	train-auc:0.50000
# [280]	eval-auc:0.50000	train-auc:0.50000
# [281]	eval-auc:0.50000	train-auc:0.50000
# [282]	eval-auc:0.50000	train-auc:0.50000
# [283]	eval-auc:0.50000	train-auc:0.50000
# [284]	eval-auc:0.50000	train-auc:0.50000
# [285]	eval-auc:0.50000	train-auc:0.50000
# [286]	eval-auc:0.50000	train-auc:0.50000
# [287]	eval-auc:0.50000	train-auc:0.50000
# [288]	eval-auc:0.50000	train-auc:0.50000
# [289]	eval-auc:0.50000	train-auc:0.50000
# [290]	eval-auc:0.50000	train-auc:0.50000
# [291]	eval-auc:0.50000	train-auc:0.50000
# [292]	eval-auc:0.50000	train-auc:0.50000
# [293]	eval-auc:0.50000	train-auc:0.50000
# [294]	eval-auc:0.50000	train-auc:0.50000
# [295]	eval-auc:0.50000	train-auc:0.50000
# [296]	eval-auc:0.50000	train-auc:0.50000
# [297]	eval-auc:0.50000	train-auc:0.50000
# [298]	eval-auc:0.50000	train-auc:0.50000
# [299]	eval-auc:0.50000	train-auc:0.50000
# [300]	eval-auc:0.50000	train-auc:0.50000
# [301]	eval-auc:0.50000	train-auc:0.50000
# [302]	eval-auc:0.50000	train-auc:0.50000
# [303]	eval-auc:0.50000	train-auc:0.50000
# [304]	eval-auc:0.50000	train-auc:0.50000
# [305]	eval-auc:0.50000	train-auc:0.50000
# [306]	eval-auc:0.50000	train-auc:0.50000
# [307]	eval-auc:0.50000	train-auc:0.50000
# [308]	eval-auc:0.50000	train-auc:0.50000
# [309]	eval-auc:0.50000	train-auc:0.50000
# [310]	eval-auc:0.50000	train-auc:0.50000
# [311]	eval-auc:0.50000	train-auc:0.50000
# [312]	eval-auc:0.50000	train-auc:0.50000
# [313]	eval-auc:0.50000	train-auc:0.50000
# [314]	eval-auc:0.50000	train-auc:0.50000
# [315]	eval-auc:0.50000	train-auc:0.50000
# [316]	eval-auc:0.50000	train-auc:0.50000
# [317]	eval-auc:0.50000	train-auc:0.50000
# [318]	eval-auc:0.50000	train-auc:0.50000
# [319]	eval-auc:0.50000	train-auc:0.50000
# [320]	eval-auc:0.50000	train-auc:0.50000
# [321]	eval-auc:0.50000	train-auc:0.50000
# [322]	eval-auc:0.50000	train-auc:0.50000
# [323]	eval-auc:0.50000	train-auc:0.50000
# [324]	eval-auc:0.50000	train-auc:0.50000
# [325]	eval-auc:0.50000	train-auc:0.50000
# [326]	eval-auc:0.50000	train-auc:0.50000
# [327]	eval-auc:0.50000	train-auc:0.50000
# [328]	eval-auc:0.50000	train-auc:0.50000
# [329]	eval-auc:0.50000	train-auc:0.50000
# [330]	eval-auc:0.50000	train-auc:0.50000
# [331]	eval-auc:0.50000	train-auc:0.50000
# [332]	eval-auc:0.50000	train-auc:0.50000
# [333]	eval-auc:0.50000	train-auc:0.50000
# [334]	eval-auc:0.50000	train-auc:0.50000
# [335]	eval-auc:0.50000	train-auc:0.50000
# [336]	eval-auc:0.50000	train-auc:0.50000
# [337]	eval-auc:0.50000	train-auc:0.50000
# [338]	eval-auc:0.50000	train-auc:0.50000
# [339]	eval-auc:0.50000	train-auc:0.50000
# [340]	eval-auc:0.50000	train-auc:0.50000
# [341]	eval-auc:0.50000	train-auc:0.50000
# [342]	eval-auc:0.50000	train-auc:0.50000
# [343]	eval-auc:0.50000	train-auc:0.50000
# [344]	eval-auc:0.50000	train-auc:0.50000
# [345]	eval-auc:0.50000	train-auc:0.50000
# [346]	eval-auc:0.50000	train-auc:0.50000
# [347]	eval-auc:0.50000	train-auc:0.50000
# [348]	eval-auc:0.50000	train-auc:0.50000
# [349]	eval-auc:0.50000	train-auc:0.50000
# [350]	eval-auc:0.50000	train-auc:0.50000
# [351]	eval-auc:0.50000	train-auc:0.50000
# [352]	eval-auc:0.50000	train-auc:0.50000
# [353]	eval-auc:0.50000	train-auc:0.50000
# [354]	eval-auc:0.50000	train-auc:0.50000
# [355]	eval-auc:0.50000	train-auc:0.50000
# [356]	eval-auc:0.50000	train-auc:0.50000
# [357]	eval-auc:0.50000	train-auc:0.50000
# [358]	eval-auc:0.50000	train-auc:0.50000
# [359]	eval-auc:0.50000	train-auc:0.50000
# [360]	eval-auc:0.50000	train-auc:0.50000
# [361]	eval-auc:0.50000	train-auc:0.50000
# [362]	eval-auc:0.50000	train-auc:0.50000
# [363]	eval-auc:0.50000	train-auc:0.50000
# [364]	eval-auc:0.50000	train-auc:0.50000
# [365]	eval-auc:0.50000	train-auc:0.50000
# [366]	eval-auc:0.50000	train-auc:0.50000
# [367]	eval-auc:0.50000	train-auc:0.50000
# [368]	eval-auc:0.50000	train-auc:0.50000
# [369]	eval-auc:0.50000	train-auc:0.50000
# [370]	eval-auc:0.50000	train-auc:0.50000
# [371]	eval-auc:0.50000	train-auc:0.50000
# [372]	eval-auc:0.50000	train-auc:0.50000
# [373]	eval-auc:0.50000	train-auc:0.50000
# [374]	eval-auc:0.50000	train-auc:0.50000
# [375]	eval-auc:0.50000	train-auc:0.50000
# ...
# [410]	eval-auc:0.50000	train-auc:0.50000
# [411]	eval-auc:0.50000	train-auc:0.50000
# [412]	eval-auc:0.50000	train-auc:0.50000
# [413]	eval-auc:0.50000	train-auc:0.50000
# [414]	eval-auc:0.50000	train-auc:0.50000
# [415]	eval-auc:0.50000	train-auc:0.50000
# [416]	eval-auc:0.50000	train-auc:0.50000
# [417]	eval-auc:0.50000	train-auc:0.50000
# [418]	eval-auc:0.50000	train-auc:0.50000
# [419]	eval-auc:0.50000	train-auc:0.50000
# [420]	eval-auc:0.50000	train-auc:0.50000
# [421]	eval-auc:0.50000	train-auc:0.50000
# [422]	eval-auc:0.50000	train-auc:0.50000
# [423]	eval-auc:0.50000	train-auc:0.50000
# [424]	eval-auc:0.50000	train-auc:0.50000
# [425]	eval-auc:0.50000	train-auc:0.50000
# [426]	eval-auc:0.50000	train-auc:0.50000
# [427]	eval-auc:0.50000	train-auc:0.50000
# [428]	eval-auc:0.50000	train-auc:0.50000
# [429]	eval-auc:0.50000	train-auc:0.50000
# [430]	eval-auc:0.50000	train-auc:0.50000
# [431]	eval-auc:0.50000	train-auc:0.50000
# [432]	eval-auc:0.50000	train-auc:0.50000
# [433]	eval-auc:0.50000	train-auc:0.50000
# [434]	eval-auc:0.50000	train-auc:0.50000
# [435]	eval-auc:0.50000	train-auc:0.50000
# [436]	eval-auc:0.50000	train-auc:0.50000
# [437]	eval-auc:0.50000	train-auc:0.50000
# [438]	eval-auc:0.50000	train-auc:0.50000
# [439]	eval-auc:0.50000	train-auc:0.50000
# [440]	eval-auc:0.50000	train-auc:0.50000
# [441]	eval-auc:0.50000	train-auc:0.50000
# [442]	eval-auc:0.50000	train-auc:0.50000
# [443]	eval-auc:0.50000	train-auc:0.50000
# [444]	eval-auc:0.50000	train-auc:0.50000
# [445]	eval-auc:0.50000	train-auc:0.50000
# [446]	eval-auc:0.50000	train-auc:0.50000
# [447]	eval-auc:0.50000	train-auc:0.50000
# [448]	eval-auc:0.50000	train-auc:0.50000
# [449]	eval-auc:0.50000	train-auc:0.50000
# [450]	eval-auc:0.50000	train-auc:0.50000
# [451]	eval-auc:0.50000	train-auc:0.50000
# [452]	eval-auc:0.50000	train-auc:0.50000
# [453]	eval-auc:0.50000	train-auc:0.50000
# [454]	eval-auc:0.50000	train-auc:0.50000
# [455]	eval-auc:0.50000	train-auc:0.50000
# [456]	eval-auc:0.50000	train-auc:0.50000
# [457]	eval-auc:0.50000	train-auc:0.50000
# [458]	eval-auc:0.50000	train-auc:0.50000
# [459]	eval-auc:0.50000	train-auc:0.50000
# [460]	eval-auc:0.50000	train-auc:0.50000
# [461]	eval-auc:0.50000	train-auc:0.50000
# [462]	eval-auc:0.50000	train-auc:0.50000
# [463]	eval-auc:0.50000	train-auc:0.50000
# [464]	eval-auc:0.50000	train-auc:0.50000
# [465]	eval-auc:0.50000	train-auc:0.50000
# [466]	eval-auc:0.50000	train-auc:0.50000
# [467]	eval-auc:0.50000	train-auc:0.50000
# [468]	eval-auc:0.50000	train-auc:0.50000
# [469]	eval-auc:0.50000	train-auc:0.50000
# [470]	eval-auc:0.50000	train-auc:0.50000
# [471]	eval-auc:0.50000	train-auc:0.50000
# [472]	eval-auc:0.50000	train-auc:0.50000
# [473]	eval-auc:0.50000	train-auc:0.50000
# [474]	eval-auc:0.50000	train-auc:0.50000
# [475]	eval-auc:0.50000	train-auc:0.50000
# [476]	eval-auc:0.50000	train-auc:0.50000
# [477]	eval-auc:0.50000	train-auc:0.50000
# [478]	eval-auc:0.50000	train-auc:0.50000
# [479]	eval-auc:0.50000	train-auc:0.50000
# [480]	eval-auc:0.50000	train-auc:0.50000
# [481]	eval-auc:0.50000	train-auc:0.50000
# [482]	eval-auc:0.50000	train-auc:0.50000
# [483]	eval-auc:0.50000	train-auc:0.50000
# [484]	eval-auc:0.50000	train-auc:0.50000
# [485]	eval-auc:0.50000	train-auc:0.50000
# [486]	eval-auc:0.50000	train-auc:0.50000
# [487]	eval-auc:0.50000	train-auc:0.50000
# [488]	eval-auc:0.50000	train-auc:0.50000
# [489]	eval-auc:0.50000	train-auc:0.50000
# [490]	eval-auc:0.50000	train-auc:0.50000
# [491]	eval-auc:0.50000	train-auc:0.50000
# [492]	eval-auc:0.50000	train-auc:0.50000
# [493]	eval-auc:0.50000	train-auc:0.50000
# [494]	eval-auc:0.50000	train-auc:0.50000
# [495]	eval-auc:0.50000	train-auc:0.50000
# [496]	eval-auc:0.50000	train-auc:0.50000
# [497]	eval-auc:0.50000	train-auc:0.50000
# [498]	eval-auc:0.50000	train-auc:0.50000
# [499]	eval-auc:0.50000	train-auc:0.50000
# [500]	eval-auc:0.50000	train-auc:0.50000
# [501]	eval-auc:0.50000	train-auc:0.50000
# [502]	eval-auc:0.50000	train-auc:0.50000
# [503]	eval-auc:0.50000	train-auc:0.50000
# [504]	eval-auc:0.50000	train-auc:0.50000
# [505]	eval-auc:0.54272	train-auc:0.75258
# [506]	eval-auc:0.54867	train-auc:0.75258
# [507]	eval-auc:0.54272	train-auc:0.75258
# [508]	eval-auc:0.54867	train-auc:0.75258
# [509]	eval-auc:0.55462	train-auc:0.75258
# [510]	eval-auc:0.54867	train-auc:0.75258
# [511]	eval-auc:0.55462	train-auc:0.75258
# [512]	eval-auc:0.55462	train-auc:0.75258
# [513]	eval-auc:0.56057	train-auc:0.75258
# [514]	eval-auc:0.56057	train-auc:0.75258
# [515]	eval-auc:0.56057	train-auc:0.77062
# [516]	eval-auc:0.56092	train-auc:0.82732
# [517]	eval-auc:0.55497	train-auc:0.82990
# [518]	eval-auc:0.56688	train-auc:0.83247
# [519]	eval-auc:0.56092	train-auc:0.83247
# [520]	eval-auc:0.57878	train-auc:0.83247
# [521]	eval-auc:0.53746	train-auc:0.83247
# [522]	eval-auc:0.54937	train-auc:0.83247
# [523]	eval-auc:0.54342	train-auc:0.83247
# [524]	eval-auc:0.54342	train-auc:0.83247
# [525]	eval-auc:0.54937	train-auc:0.83247
# [526]	eval-auc:0.55532	train-auc:0.83247
# [527]	eval-auc:0.54937	train-auc:0.83247
# [528]	eval-auc:0.55532	train-auc:0.85309
# [529]	eval-auc:0.54937	train-auc:0.87113
# [530]	eval-auc:0.54937	train-auc:0.87629
# [531]	eval-auc:0.55532	train-auc:0.87629
# [532]	eval-auc:0.56127	train-auc:0.87629
# [533]	eval-auc:0.55532	train-auc:0.87629
# [534]	eval-auc:0.56127	train-auc:0.87629
# [535]	eval-auc:0.56127	train-auc:0.87629
# [536]	eval-auc:0.56127	train-auc:0.87629
# [537]	eval-auc:0.56723	train-auc:0.87629
# [538]	eval-auc:0.57318	train-auc:0.87629
# [539]	eval-auc:0.53782	train-auc:0.87629
# [540]	eval-auc:0.53782	train-auc:0.87629
# [541]	eval-auc:0.53782	train-auc:0.87629
# [542]	eval-auc:0.54377	train-auc:0.87629
# [543]	eval-auc:0.54377	train-auc:0.88660
# [544]	eval-auc:0.54377	train-auc:0.89948
# [545]	eval-auc:0.51436	train-auc:0.90206
# [546]	eval-auc:0.48494	train-auc:0.90206
# [547]	eval-auc:0.48494	train-auc:0.90206
# [548]	eval-auc:0.48494	train-auc:0.90464
# [549]	eval-auc:0.49090	train-auc:0.90464
# [550]	eval-auc:0.49090	train-auc:0.90722
# [551]	eval-auc:0.49090	train-auc:0.92010
# [552]	eval-auc:0.49090	train-auc:0.93814
# [553]	eval-auc:0.49090	train-auc:0.94330
# [554]	eval-auc:0.49685	train-auc:0.94588
# [555]	eval-auc:0.49685	train-auc:0.94588
# [556]	eval-auc:0.49685	train-auc:0.95103
# [557]	eval-auc:0.47934	train-auc:0.95103
# [558]	eval-auc:0.47934	train-auc:0.95103
# [559]	eval-auc:0.48529	train-auc:0.95103
# [560]	eval-auc:0.49125	train-auc:0.95103
# [561]	eval-auc:0.48529	train-auc:0.95103
# [562]	eval-auc:0.49125	train-auc:0.95103
# [563]	eval-auc:0.49720	train-auc:0.95103
# [564]	eval-auc:0.46779	train-auc:0.95103
# [565]	eval-auc:0.48564	train-auc:0.95103
# [566]	eval-auc:0.48564	train-auc:0.95103
# [567]	eval-auc:0.49160	train-auc:0.95103
# [568]	eval-auc:0.49160	train-auc:0.95103
# [569]	eval-auc:0.49755	train-auc:0.95103
# [570]	eval-auc:0.50350	train-auc:0.95103
# [571]	eval-auc:0.50350	train-auc:0.95103
# [572]	eval-auc:0.50945	train-auc:0.95103
# [573]	eval-auc:0.47409	train-auc:0.95103
# [574]	eval-auc:0.48004	train-auc:0.95361
# [575]	eval-auc:0.48599	train-auc:0.95876
# [576]	eval-auc:0.48004	train-auc:0.95876
# [577]	eval-auc:0.48599	train-auc:0.96392
# [578]	eval-auc:0.48599	train-auc:0.96392
# [579]	eval-auc:0.48599	train-auc:0.96649
# [580]	eval-auc:0.48599	train-auc:0.96649
# [581]	eval-auc:0.48599	train-auc:0.96649
# [582]	eval-auc:0.48599	train-auc:0.96649
# [583]	eval-auc:0.48599	train-auc:0.96649
# [584]	eval-auc:0.48599	train-auc:0.96649
# [585]	eval-auc:0.48599	train-auc:0.96649
# [586]	eval-auc:0.48599	train-auc:0.96649
# [587]	eval-auc:0.48599	train-auc:0.96649
# [588]	eval-auc:0.48599	train-auc:0.96649
# [589]	eval-auc:0.48599	train-auc:0.96649
# [590]	eval-auc:0.49195	train-auc:0.96649
# [591]	eval-auc:0.49195	train-auc:0.96649
# [592]	eval-auc:0.49195	train-auc:0.96649
# [593]	eval-auc:0.49195	train-auc:0.96649
# [594]	eval-auc:0.49195	train-auc:0.96649
# [595]	eval-auc:0.49790	train-auc:0.96649
# [596]	eval-auc:0.49195	train-auc:0.96649
# [597]	eval-auc:0.46849	train-auc:0.96649
# [598]	eval-auc:0.46849	train-auc:0.96649
# [599]	eval-auc:0.46849	train-auc:0.96649
# [600]	eval-auc:0.46849	train-auc:0.96649
# [601]	eval-auc:0.46849	train-auc:0.96649
# [602]	eval-auc:0.46253	train-auc:0.96649
# [603]	eval-auc:0.46849	train-auc:0.96649
# [604]	eval-auc:0.46253	train-auc:0.96649
# [605]	eval-auc:0.46253	train-auc:0.96649
# [606]	eval-auc:0.46253	train-auc:0.96649
# [607]	eval-auc:0.46253	train-auc:0.96649
# [608]	eval-auc:0.46253	train-auc:0.96649
# [609]	eval-auc:0.46849	train-auc:0.96649
# [610]	eval-auc:0.46849	train-auc:0.96649
# [611]	eval-auc:0.46849	train-auc:0.96649
# [612]	eval-auc:0.46849	train-auc:0.96649
# [613]	eval-auc:0.46849	train-auc:0.96649
# [614]	eval-auc:0.46849	train-auc:0.96649
# [615]	eval-auc:0.46849	train-auc:0.96649
# [616]	eval-auc:0.46849	train-auc:0.96649
# [617]	eval-auc:0.46849	train-auc:0.96649
# [618]	eval-auc:0.46849	train-auc:0.96649
# [619]	eval-auc:0.46849	train-auc:0.96649
# [620]	eval-auc:0.46849	train-auc:0.96649
# [621]	eval-auc:0.46849	train-auc:0.96649
# [622]	eval-auc:0.46849	train-auc:0.96649
# [623]	eval-auc:0.46849	train-auc:0.96649
# [624]	eval-auc:0.46849	train-auc:0.96649
# [625]	eval-auc:0.46849	train-auc:0.96649
# [626]	eval-auc:0.47444	train-auc:0.96649
# [627]	eval-auc:0.47444	train-auc:0.96649
# [628]	eval-auc:0.47444	train-auc:0.96649
# [629]	eval-auc:0.47444	train-auc:0.96907
# [630]	eval-auc:0.48039	train-auc:0.96907
# [631]	eval-auc:0.48039	train-auc:0.96907
# [632]	eval-auc:0.48039	train-auc:0.97423
# [633]	eval-auc:0.48039	train-auc:0.97423
# [634]	eval-auc:0.48039	train-auc:0.97423
# [635]	eval-auc:0.48039	train-auc:0.97423
# [636]	eval-auc:0.48039	train-auc:0.97423
# [637]	eval-auc:0.48039	train-auc:0.97423
# [638]	eval-auc:0.48039	train-auc:0.97423
# [639]	eval-auc:0.48039	train-auc:0.97423
# [640]	eval-auc:0.48039	train-auc:0.97423
# [641]	eval-auc:0.48039	train-auc:0.97423
# [642]	eval-auc:0.48039	train-auc:0.97423
# [643]	eval-auc:0.48039	train-auc:0.97423
# [644]	eval-auc:0.48635	train-auc:0.97423
# [645]	eval-auc:0.48635	train-auc:0.97423
# [646]	eval-auc:0.48635	train-auc:0.97423
# [647]	eval-auc:0.48635	train-auc:0.97423
# [648]	eval-auc:0.48635	train-auc:0.97423
# [649]	eval-auc:0.48635	train-auc:0.97423
# [650]	eval-auc:0.48635	train-auc:0.97423
# [651]	eval-auc:0.48635	train-auc:0.97423
# [652]	eval-auc:0.48635	train-auc:0.97423
# [653]	eval-auc:0.48635	train-auc:0.97423
# [654]	eval-auc:0.48635	train-auc:0.97423
# [655]	eval-auc:0.48635	train-auc:0.97423
# [656]	eval-auc:0.48635	train-auc:0.97423
# [657]	eval-auc:0.48635	train-auc:0.97423
# [658]	eval-auc:0.48635	train-auc:0.97423
# [659]	eval-auc:0.48635	train-auc:0.97423
# [660]	eval-auc:0.48635	train-auc:0.97423
# [661]	eval-auc:0.48635	train-auc:0.97423
# [662]	eval-auc:0.48635	train-auc:0.97423
# [663]	eval-auc:0.48635	train-auc:0.97423
# [664]	eval-auc:0.48635	train-auc:0.97423
# [665]	eval-auc:0.48635	train-auc:0.97423
# [666]	eval-auc:0.48635	train-auc:0.97423
# [667]	eval-auc:0.48635	train-auc:0.97423
# [668]	eval-auc:0.48635	train-auc:0.97423
# [669]	eval-auc:0.48635	train-auc:0.97423
# [670]	eval-auc:0.48635	train-auc:0.97680
# [671]	eval-auc:0.48635	train-auc:0.98196
# [672]	eval-auc:0.48635	train-auc:0.98196
# [673]	eval-auc:0.48635	train-auc:0.98196
# [674]	eval-auc:0.48635	train-auc:0.98196
# [675]	eval-auc:0.48635	train-auc:0.98196
# [676]	eval-auc:0.48635	train-auc:0.98196
# [677]	eval-auc:0.49230	train-auc:0.98711
# [678]	eval-auc:0.49230	train-auc:0.98711
# [679]	eval-auc:0.49230	train-auc:0.98711
# [680]	eval-auc:0.49230	train-auc:0.98711
# [681]	eval-auc:0.49825	train-auc:0.98711
# [682]	eval-auc:0.49825	train-auc:0.98711
# [683]	eval-auc:0.49825	train-auc:0.98711
# [684]	eval-auc:0.49825	train-auc:0.98969
# [685]	eval-auc:0.49825	train-auc:0.98969
# [686]	eval-auc:0.49825	train-auc:0.98969
# [687]	eval-auc:0.49825	train-auc:0.98969
# [688]	eval-auc:0.49825	train-auc:0.98969
# [689]	eval-auc:0.49825	train-auc:0.98969
# [690]	eval-auc:0.49825	train-auc:0.98969
# [691]	eval-auc:0.49825	train-auc:0.98969
# [692]	eval-auc:0.49825	train-auc:0.98969
# [693]	eval-auc:0.49825	train-auc:0.98969
# [694]	eval-auc:0.49825	train-auc:0.98969
# [695]	eval-auc:0.49825	train-auc:0.98969
# [696]	eval-auc:0.49825	train-auc:0.98969
# [697]	eval-auc:0.49825	train-auc:0.98969
# [698]	eval-auc:0.49825	train-auc:0.98969
# [699]	eval-auc:0.49825	train-auc:0.98969
# [700]	eval-auc:0.49825	train-auc:0.98969
# [701]	eval-auc:0.49825	train-auc:0.98969
# [702]	eval-auc:0.49825	train-auc:0.98969
# [703]	eval-auc:0.49825	train-auc:0.98969
# [704]	eval-auc:0.49825	train-auc:0.98969
# [705]	eval-auc:0.49825	train-auc:0.98969
# [706]	eval-auc:0.49825	train-auc:0.98969
# [707]	eval-auc:0.49825	train-auc:0.98969
# [708]	eval-auc:0.49825	train-auc:0.98969
# [709]	eval-auc:0.49825	train-auc:0.98969
# [710]	eval-auc:0.49825	train-auc:0.98969
# [711]	eval-auc:0.49825	train-auc:0.98969
# [712]	eval-auc:0.49825	train-auc:0.98969
# [713]	eval-auc:0.49825	train-auc:0.98969
# [714]	eval-auc:0.49825	train-auc:0.98969
# [715]	eval-auc:0.49825	train-auc:0.98969
# [716]	eval-auc:0.49825	train-auc:0.98969
# [717]	eval-auc:0.49825	train-auc:0.98969
# [718]	eval-auc:0.49825	train-auc:0.98969
# [719]	eval-auc:0.49825	train-auc:0.98969
# [720]	eval-auc:0.49825	train-auc:0.98969
# [721]	eval-auc:0.49825	train-auc:0.98969
# [722]	eval-auc:0.49825	train-auc:0.98969
# [723]	eval-auc:0.49825	train-auc:0.98969
# [724]	eval-auc:0.49825	train-auc:0.98969
# [725]	eval-auc:0.49825	train-auc:0.98969
# [726]	eval-auc:0.49825	train-auc:0.98969
# [727]	eval-auc:0.49825	train-auc:0.98969
# [728]	eval-auc:0.49825	train-auc:0.98969
# [729]	eval-auc:0.49825	train-auc:0.98969
# [730]	eval-auc:0.49825	train-auc:0.98969
# [731]	eval-auc:0.49825	train-auc:0.98969
# [732]	eval-auc:0.49825	train-auc:0.98969
# [733]	eval-auc:0.49825	train-auc:0.98969
# [734]	eval-auc:0.50420	train-auc:0.98969
# [735]	eval-auc:0.50420	train-auc:0.98969
# [736]	eval-auc:0.50420	train-auc:0.98969
# [737]	eval-auc:0.50420	train-auc:0.98969
# [738]	eval-auc:0.50420	train-auc:0.98969
# [739]	eval-auc:0.50420	train-auc:0.98969
# [740]	eval-auc:0.50420	train-auc:0.98969
# [741]	eval-auc:0.50420	train-auc:0.98969
# [742]	eval-auc:0.50420	train-auc:0.98969
# [743]	eval-auc:0.50420	train-auc:0.98969
# [744]	eval-auc:0.50420	train-auc:0.98969
# [745]	eval-auc:0.50420	train-auc:0.98969
# [746]	eval-auc:0.50420	train-auc:0.98969
# [747]	eval-auc:0.50420	train-auc:0.98969
# [748]	eval-auc:0.50420	train-auc:0.98969
# [749]	eval-auc:0.50420	train-auc:0.98969
# [750]	eval-auc:0.50420	train-auc:0.98969
# [751]	eval-auc:0.50420	train-auc:0.98969
# [752]	eval-auc:0.51015	train-auc:0.98969
# [753]	eval-auc:0.50420	train-auc:0.98969
# [754]	eval-auc:0.50420	train-auc:0.98969
# [755]	eval-auc:0.50420	train-auc:0.98969
# [756]	eval-auc:0.51015	train-auc:0.99227
# [757]	eval-auc:0.51015	train-auc:0.99227
# [758]	eval-auc:0.51015	train-auc:0.99484
# [759]	eval-auc:0.51015	train-auc:0.99484
# [760]	eval-auc:0.51015	train-auc:0.99484
# [761]	eval-auc:0.51015	train-auc:0.99484
# [762]	eval-auc:0.51015	train-auc:0.99484
# [763]	eval-auc:0.51015	train-auc:1.00000
# [764]	eval-auc:0.51015	train-auc:1.00000
# [765]	eval-auc:0.51015	train-auc:1.00000
# [766]	eval-auc:0.51015	train-auc:1.00000
# [767]	eval-auc:0.51015	train-auc:1.00000
# [768]	eval-auc:0.51015	train-auc:1.00000
# [769]	eval-auc:0.51015	train-auc:1.00000
# [770]	eval-auc:0.51015	train-auc:1.00000
# [771]	eval-auc:0.51015	train-auc:1.00000
# [772]	eval-auc:0.51015	train-auc:1.00000
# [773]	eval-auc:0.51015	train-auc:1.00000
# [774]	eval-auc:0.51015	train-auc:1.00000
# [775]	eval-auc:0.51015	train-auc:1.00000
# [776]	eval-auc:0.51015	train-auc:1.00000
# [777]	eval-auc:0.51015	train-auc:1.00000
# [778]	eval-auc:0.51015	train-auc:1.00000
# [779]	eval-auc:0.51015	train-auc:1.00000
# [780]	eval-auc:0.51015	train-auc:1.00000
# [781]	eval-auc:0.51015	train-auc:1.00000
# [782]	eval-auc:0.51015	train-auc:1.00000
# [783]	eval-auc:0.51015	train-auc:1.00000
# [784]	eval-auc:0.51015	train-auc:1.00000
# [785]	eval-auc:0.51611	train-auc:1.00000
# [786]	eval-auc:0.51611	train-auc:1.00000
# [787]	eval-auc:0.51611	train-auc:1.00000
# [788]	eval-auc:0.51611	train-auc:1.00000
# [789]	eval-auc:0.51611	train-auc:1.00000
# [790]	eval-auc:0.51611	train-auc:1.00000
# [791]	eval-auc:0.51611	train-auc:1.00000
# [792]	eval-auc:0.51611	train-auc:1.00000
# [793]	eval-auc:0.51611	train-auc:1.00000
# [794]	eval-auc:0.51611	train-auc:1.00000
# [795]	eval-auc:0.51611	train-auc:1.00000
# [796]	eval-auc:0.51611	train-auc:1.00000
# [797]	eval-auc:0.51611	train-auc:1.00000
# [798]	eval-auc:0.51611	train-auc:1.00000
# [799]	eval-auc:0.51611	train-auc:1.00000

# %%
f1_scores
# Out:
# [0.09999999999999999,
#  0.186046511627907,
#  0.2631578947368421,
#  0.2926829268292683,
#  0.3255813953488372,
#  0.21276595744680848,
#  0.3333333333333333,
#  0.39999999999999997,
#  0.3043478260869565,
#  0.22727272727272727]
